# %%
import pandas as pd

# %%
df = pd.read_csv('output_data/cities.csv')
df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Atuona           0      PF  1566338730        74  -9.80 -139.03
# 1    Quelimane          20      MZ  1566338731        77 -17.88   36.89
# 2         Hilo          40      US  1566338732        66  19.71 -155.08
# 3      Te Anau         100      NZ  1566338734        84 -45.41  167.72
# 4  Port Alfred           4      ZA  1566338735        92 -33.59   26.89
#
#    Max Temp  Wind Speed
# 0     79.97       20.58
# 1     69.80        8.05
# 2     84.20        4.70
# 3     38.21        3.91
# 4     55.99        3.00

# %%
html_data = df.to_html

# %%
html_data
# Out:
# <bound method DataFrame.to_html of                     City  Cloudiness Country        Date  Humidity    Lat  \
# 0                 Atuona           0      PF  1566338730        74  -9.80
# 1              Quelimane          20      MZ  1566338731        77 -17.88
# 2                   Hilo          40      US  1566338732        66  19.71
# 3                Te Anau         100      NZ  1566338734        84 -45.41
# 4            Port Alfred           4      ZA  1566338735        92 -33.59
# 5                   Teya          75      MX  1566338736        94  21.05
# 6                Ruidoso           1      US  1566338737        46  33.33
# 7              Busselton           0      AU  1566338738        65 -33.64
# 8             Porto Belo          75      BR  1566338739        72 -27.15
# 9              Upernavik         100      GL  1566338742        86  72.79
# 10                   Ati         100      TD  1566338743        83  13.21
# ...
