# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import seaborn as sns

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
city_dictionary_list = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 652

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

print('--- Beginning Data Retrieval ---')

counter = 1

for city in cities:
    print(f"Processing city #{counter} | {city}")
    counter += 1
    query_url = f"{url}appid={api_key}&units={units}&q={city}"
    
    # weather_data is the dictionary
    request_data = requests.get(query_url)
    time.sleep(1)
    
    if request_data.status_code == 404:
        print('City not found', city)
    else:
        weather_data = request_data.json()

        weather_dict = {
            'City': weather_data['name'],
            'Cloudiness': weather_data['clouds']['all'],
            'Country': weather_data['sys']['country'],
            'Date': weather_data['dt'],
            'Humidity': weather_data['main']['humidity'],
            'Lat': weather_data['coord']['lat'],
            'Lng': weather_data['coord']['lon'],
            'Max Temp': weather_data['main']['temp_max'],
            'Wind Speed': weather_data['wind']['speed']
        }

        # Add each dictionary to our empty list, one at a time
        city_dictionary_list.append(weather_dict)
    
print('--- Data Retrieval Complete ---')
# Out:
# --- Beginning Data Retrieval ---
# Processing city #1 | rikitea
# Processing city #2 | tasiilaq
# Processing city #3 | mataura
# Processing city #4 | jalu
# Processing city #5 | hobart
# Processing city #6 | le mars
# Processing city #7 | bluff
# Processing city #8 | airai
# Processing city #9 | butaritari
# Processing city #10 | busselton
# Processing city #11 | zhangye
# Processing city #12 | illoqqortoormiut
# City not found illoqqortoormiut
# Processing city #13 | ushuaia
# Processing city #14 | barentsburg
# City not found barentsburg
# Processing city #15 | caravelas
# Processing city #16 | port elizabeth
# Processing city #17 | new norfolk
# Processing city #18 | hermanus
# Processing city #19 | ribeira grande
# Processing city #20 | belushya guba
# City not found belushya guba
# Processing city #21 | nantucket
# Processing city #22 | aller
# Processing city #23 | montepuez
# Processing city #24 | tsihombe
# City not found tsihombe
# Processing city #25 | dubbo
# Processing city #26 | bredasdorp
# Processing city #27 | thunder bay
# Processing city #28 | itarema
# Processing city #29 | aleksandrov gay
# Processing city #30 | chokurdakh
# Processing city #31 | victoria
# Processing city #32 | havelock
# Processing city #33 | staryy nadym
# Processing city #34 | dunedin
# Processing city #35 | visnes
# Processing city #36 | jamestown
# Processing city #37 | hovd
# Processing city #38 | mutsamudu
# City not found mutsamudu
# Processing city #39 | albany
# Processing city #40 | guerrero negro
# Processing city #41 | murray bridge
# Processing city #42 | cheuskiny
# City not found cheuskiny
# Processing city #43 | piqua
# Processing city #44 | punta arenas
# Processing city #45 | vasilsursk
# Processing city #46 | east london
# Processing city #47 | port alfred
# Processing city #48 | mandalgovi
# Processing city #49 | thompson
# Processing city #50 | cape town
# Processing city #51 | kirakira
# Processing city #52 | natal
# Processing city #53 | manga
# Processing city #54 | pangnirtung
# Processing city #55 | jodhpur
# Processing city #56 | takoradi
# Processing city #57 | mys shmidta
# City not found mys shmidta
# Processing city #58 | taolanaro
# City not found taolanaro
# Processing city #59 | luderitz
# Processing city #60 | sept-iles
# Processing city #61 | basco
# Processing city #62 | ancud
# Processing city #63 | chabahar
# Processing city #64 | castro
# Processing city #65 | ponta do sol
# Processing city #66 | husavik
# Processing city #67 | sisimiut
# Processing city #68 | banda aceh
# Processing city #69 | nikolskoye
# Processing city #70 | tromso
# Processing city #71 | esperance
# Processing city #72 | barrow
# Processing city #73 | cidreira
# Processing city #74 | fare
# Processing city #75 | hastings
# Processing city #76 | beringovskiy
# Processing city #77 | miri
# Processing city #78 | saldanha
# Processing city #79 | kavieng
# Processing city #80 | ahuimanu
# Processing city #81 | vestmanna
# Processing city #82 | khash
# Processing city #83 | merzifon
# Processing city #84 | norfolk
# Processing city #85 | vao
# Processing city #86 | svetlaya
# Processing city #87 | pangoa
# Processing city #88 | kiama
# Processing city #89 | santiago del estero
# Processing city #90 | nemuro
# Processing city #91 | kalmunai
# Processing city #92 | hithadhoo
# Processing city #93 | avarua
# Processing city #94 | barlinek
# Processing city #95 | santa fe
# Processing city #96 | jiroft
# City not found jiroft
# Processing city #97 | faya
# Processing city #98 | ovalle
# Processing city #99 | grand river south east
# City not found grand river south east
# Processing city #100 | lagoa
# Processing city #101 | grande-synthe
# Processing city #102 | kapaa
# Processing city #103 | kidal
# Processing city #104 | phan thiet
# Processing city #105 | sitka
# Processing city #106 | upernavik
# Processing city #107 | saint george
# Processing city #108 | isangel
# Processing city #109 | huarmey
# Processing city #110 | shubarshi
# Processing city #111 | nieuw amsterdam
# Processing city #112 | sardinia
# Processing city #113 | olafsvik
# City not found olafsvik
# Processing city #114 | saint-philippe
# Processing city #115 | inuvik
# Processing city #116 | fortuna
# Processing city #117 | eenhana
# Processing city #118 | avera
# Processing city #119 | provideniya
# Processing city #120 | atar
# Processing city #121 | bengkulu
# City not found bengkulu
# Processing city #122 | siderno
# Processing city #123 | samsun
# Processing city #124 | tagusao
# Processing city #125 | klaksvik
# Processing city #126 | puerto ayora
# Processing city #127 | kedrovyy
# Processing city #128 | qaanaaq
# Processing city #129 | bethel
# Processing city #130 | hasaki
# Processing city #131 | tuatapere
# Processing city #132 | fatehabad
# Processing city #133 | lanzhou
# Processing city #134 | mahebourg
# Processing city #135 | mar del plata
# Processing city #136 | betioky
# City not found betioky
# Processing city #137 | morondava
# Processing city #138 | severo-kurilsk
# Processing city #139 | gat
# Processing city #140 | tabuk
# Processing city #141 | nuqui
# Processing city #142 | souillac
# Processing city #143 | atuona
# Processing city #144 | riaba
# City not found riaba
# Processing city #145 | kruisfontein
# Processing city #146 | sarkand
# Processing city #147 | ures
# Processing city #148 | ardmore
# Processing city #149 | faanui
# Processing city #150 | nioki
# Processing city #151 | sakakah
# City not found sakakah
# Processing city #152 | port hawkesbury
# Processing city #153 | cherskiy
# Processing city #154 | aykhal
# Processing city #155 | lerum
# Processing city #156 | ngunguru
# Processing city #157 | hilo
# Processing city #158 | kodiak
# Processing city #159 | vaini
# Processing city #160 | kovdor
# Processing city #161 | hjelset
# Processing city #162 | quatre cocos
# Processing city #163 | georgetown
# Processing city #164 | macon
# Processing city #165 | necochea
# Processing city #166 | vila do maio
# Processing city #167 | yangambi
# Processing city #168 | attawapiskat
# City not found attawapiskat
# Processing city #169 | pedernales
# Processing city #170 | sorong
# Processing city #171 | karratha
# Processing city #172 | tome
# Processing city #173 | clyde river
# Processing city #174 | high prairie
# Processing city #175 | pemba
# Processing city #176 | xining
# Processing city #177 | puerto madryn
# Processing city #178 | kavaratti
# Processing city #179 | geresk
# City not found geresk
# Processing city #180 | mangai
# Processing city #181 | tsabong
# Processing city #182 | benha
# City not found benha
# Processing city #183 | yar-sale
# Processing city #184 | bahia honda
# Processing city #185 | soyo
# Processing city #186 | shimoda
# Processing city #187 | ibipeba
# Processing city #188 | ilhabela
# Processing city #189 | otradnoye
# Processing city #190 | parrita
# Processing city #191 | puerto leguizamo
# Processing city #192 | bilibino
# Processing city #193 | mount isa
# Processing city #194 | constitucion
# Processing city #195 | kaitangata
# Processing city #196 | vanimo
# Processing city #197 | zvenigorod
# Processing city #198 | liuli
# Processing city #199 | whittlesea
# Processing city #200 | naze
# Processing city #201 | amderma
# City not found amderma
# Processing city #202 | rincon
# Processing city #203 | taoudenni
# Processing city #204 | vardo
# Processing city #205 | ginir
# Processing city #206 | port hedland
# Processing city #207 | kailua
# Processing city #208 | lufilufi
# Processing city #209 | kristinehamn
# Processing city #210 | punta alta
# Processing city #211 | inirida
# Processing city #212 | kushmurun
# City not found kushmurun
# Processing city #213 | broome
# Processing city #214 | kez
# Processing city #215 | teya
# Processing city #216 | nome
# Processing city #217 | tual
# Processing city #218 | klobuck
# Processing city #219 | rungata
# City not found rungata
# Processing city #220 | mahajanga
# Processing city #221 | kahului
# Processing city #222 | san mateo ixtatan
# Processing city #223 | carnarvon
# Processing city #224 | marrakesh
# Processing city #225 | xichang
# Processing city #226 | nouadhibou
# Processing city #227 | aklavik
# Processing city #228 | vaitupu
# City not found vaitupu
# Processing city #229 | khatanga
# Processing city #230 | labuhan
# Processing city #231 | tuktoyaktuk
# Processing city #232 | san policarpo
# Processing city #233 | anadyr
# Processing city #234 | arraial do cabo
# Processing city #235 | ambon
# Processing city #236 | tiksi
# Processing city #237 | finschhafen
# Processing city #238 | qasigiannguit
# Processing city #239 | longyearbyen
# Processing city #240 | vestmannaeyjar
# Processing city #241 | vaskut
# Processing city #242 | marawi
# Processing city #243 | chuy
# Processing city #244 | nago
# Processing city #245 | ahipara
# Processing city #246 | phan rang
# City not found phan rang
# Processing city #247 | luanda
# Processing city #248 | karcsa
# Processing city #249 | lebu
# Processing city #250 | ekhabi
# Processing city #251 | nizhneyansk
# City not found nizhneyansk
# Processing city #252 | whitehorse
# Processing city #253 | columbus
# Processing city #254 | tambacounda
# Processing city #255 | umm lajj
# Processing city #256 | ozernovskiy
# Processing city #257 | leningradskiy
# Processing city #258 | garowe
# Processing city #259 | benghazi
# Processing city #260 | san andres
# Processing city #261 | praia
# Processing city #262 | salalah
# Processing city #263 | halifax
# Processing city #264 | nyeri
# Processing city #265 | san cristobal
# Processing city #266 | lumeje
# Processing city #267 | tanshui
# City not found tanshui
# Processing city #268 | saint anthony
# Processing city #269 | kilingi-nomme
# Processing city #270 | plainview
# Processing city #271 | auki
# Processing city #272 | karaul
# City not found karaul
# Processing city #273 | la orilla
# Processing city #274 | suzhou
# Processing city #275 | lata
# Processing city #276 | lake havasu city
# Processing city #277 | brandon
# Processing city #278 | karpuninskiy
# City not found karpuninskiy
# Processing city #279 | santa rosa
# Processing city #280 | piterka
# Processing city #281 | marcona
# City not found marcona
# Processing city #282 | viedma
# Processing city #283 | zharkent
# Processing city #284 | chitaga
# Processing city #285 | baruun-urt
# Processing city #286 | waipawa
# Processing city #287 | oksfjord
# Processing city #288 | los llanos de aridane
# Processing city #289 | torbay
# Processing city #290 | baiima
# Processing city #291 | erenhot
# Processing city #292 | ciudad bolivar
# Processing city #293 | dullewala
# Processing city #294 | jinchang
# Processing city #295 | kungsbacka
# Processing city #296 | ler
# Processing city #297 | hofn
# Processing city #298 | sao felix do xingu
# Processing city #299 | axim
# Processing city #300 | goderich
# Processing city #301 | pisco
# Processing city #302 | ust-omchug
# Processing city #303 | kangaatsiaq
# Processing city #304 | kodinar
# Processing city #305 | krasnoselkup
# City not found krasnoselkup
# Processing city #306 | jacareacanga
# Processing city #307 | tsentralnyy
# City not found tsentralnyy
# Processing city #308 | pevek
# Processing city #309 | alta floresta
# Processing city #310 | luganville
# Processing city #311 | sioux lookout
# Processing city #312 | kongolo
# Processing city #313 | mongoumba
# Processing city #314 | shitanjing
# Processing city #315 | ossora
# Processing city #316 | hamilton
# Processing city #317 | saint-francois
# Processing city #318 | samarai
# Processing city #319 | tumannyy
# City not found tumannyy
# Processing city #320 | kimbe
# Processing city #321 | labelle
# Processing city #322 | lorengau
# Processing city #323 | mount gambier
# Processing city #324 | elbrus
# Processing city #325 | corn island
# Processing city #326 | korla
# City not found korla
# Processing city #327 | hirara
# Processing city #328 | udaipur
# Processing city #329 | santo antonio do monte
# Processing city #330 | taiyuan
# Processing city #331 | talnakh
# Processing city #332 | samusu
# City not found samusu
# Processing city #333 | iqaluit
# Processing city #334 | ambilobe
# Processing city #335 | nyurba
# Processing city #336 | ingham
# Processing city #337 | manhattan
# Processing city #338 | negombo
# Processing city #339 | solovetskiy
# City not found solovetskiy
# Processing city #340 | kalianget
# Processing city #341 | ucluelet
# Processing city #342 | warqla
# City not found warqla
# Processing city #343 | pacific grove
# Processing city #344 | aubenas
# Processing city #345 | nanortalik
# Processing city #346 | hambantota
# Processing city #347 | lompoc
# Processing city #348 | orgun
# City not found orgun
# Processing city #349 | jiayuguan
# Processing city #350 | kamaishi
# Processing city #351 | dikson
# Processing city #352 | abu dhabi
# Processing city #353 | palabuhanratu
# City not found palabuhanratu
# Processing city #354 | zemio
# Processing city #355 | nikolayevsk-na-amure
# Processing city #356 | venado
# Processing city #357 | trelew
# Processing city #358 | yellowknife
# Processing city #359 | arkhara
# Processing city #360 | weligama
# Processing city #361 | oussouye
# Processing city #362 | tuzla
# Processing city #363 | manavalakurichi
# Processing city #364 | portland
# Processing city #365 | bontang
# Processing city #366 | bitung
# Processing city #367 | geraldton
# Processing city #368 | fairbanks
# Processing city #369 | shimizu
# Processing city #370 | ulaanbaatar
# Processing city #371 | ternate
# Processing city #372 | mildura
# Processing city #373 | poum
# Processing city #374 | barawe
# City not found barawe
# Processing city #375 | alanya
# Processing city #376 | sao joao da barra
# Processing city #377 | grindavik
# Processing city #378 | pescia
# Processing city #379 | laguna
# Processing city #380 | chernyshevskiy
# Processing city #381 | cap malheureux
# Processing city #382 | sao filipe
# Processing city #383 | manaure
# Processing city #384 | ust-maya
# Processing city #385 | atikokan
# Processing city #386 | kihei
# Processing city #387 | matamoros
# Processing city #388 | southampton
# Processing city #389 | roald
# Processing city #390 | praia da vitoria
# Processing city #391 | ewa beach
# Processing city #392 | alyangula
# Processing city #393 | litovko
# Processing city #394 | ayan
# Processing city #395 | nizwa
# Processing city #396 | kawalu
# Processing city #397 | marsh harbour
# Processing city #398 | corinto
# Processing city #399 | kaeo
# Processing city #400 | marolambo
# Processing city #401 | manggar
# Processing city #402 | rundu
# Processing city #403 | tabiauea
# City not found tabiauea
# Processing city #404 | sorab
# Processing city #405 | raga
# City not found raga
# Processing city #406 | byron bay
# Processing city #407 | bayangol
# Processing city #408 | beacon
# Processing city #409 | cranbrook
# Processing city #410 | bambous virieux
# Processing city #411 | rameswaram
# Processing city #412 | novyy urengoy
# Processing city #413 | ostrovnoy
# Processing city #414 | novikovo
# Processing city #415 | porto nacional
# Processing city #416 | galle
# Processing city #417 | vostok
# Processing city #418 | sorvag
# City not found sorvag
# Processing city #419 | sobolevo
# Processing city #420 | sentyabrskiy
# City not found sentyabrskiy
# Processing city #421 | buala
# Processing city #422 | norman wells
# Processing city #423 | kingston upon hull
# City not found kingston upon hull
# Processing city #424 | san patricio
# Processing city #425 | hay river
# Processing city #426 | bambanglipuro
# Processing city #427 | champerico
# Processing city #428 | narragansett
# Processing city #429 | palasa
# City not found palasa
# Processing city #430 | westport
# Processing city #431 | katsuura
# Processing city #432 | ueckermunde
# Processing city #433 | salihli
# Processing city #434 | terrace bay
# Processing city #435 | saskylakh
# Processing city #436 | nguiu
# City not found nguiu
# Processing city #437 | fukue
# Processing city #438 | thinadhoo
# Processing city #439 | lysva
# Processing city #440 | isla mujeres
# Processing city #441 | porto santo
# City not found porto santo
# Processing city #442 | ereymentau
# Processing city #443 | haines junction
# Processing city #444 | katobu
# Processing city #445 | marathon
# Processing city #446 | wajid
# Processing city #447 | ruteng
# Processing city #448 | thessalon
# Processing city #449 | huejucar
# Processing city #450 | mezofalva
# Processing city #451 | kurilsk
# Processing city #452 | iturama
# Processing city #453 | solnechnyy
# Processing city #454 | delijan
# Processing city #455 | anchorage
# Processing city #456 | aasiaat
# Processing city #457 | granard
# Processing city #458 | tilichiki
# Processing city #459 | erzin
# Processing city #460 | chekhov
# Processing city #461 | portobelo
# Processing city #462 | ponta delgada
# Processing city #463 | tura
# Processing city #464 | ozgon
# City not found ozgon
# Processing city #465 | florianopolis
# Processing city #466 | vagur
# Processing city #467 | mattru
# Processing city #468 | oranjemund
# Processing city #469 | saleaula
# City not found saleaula
# Processing city #470 | uaua
# Processing city #471 | maldonado
# Processing city #472 | srivardhan
# Processing city #473 | murakami
# Processing city #474 | nabire
# Processing city #475 | kashary
# Processing city #476 | zonguldak
# Processing city #477 | nedjo
# Processing city #478 | codrington
# Processing city #479 | aitape
# Processing city #480 | kropotkin
# Processing city #481 | burias
# Processing city #482 | santa cruz de tenerife
# Processing city #483 | san matias
# Processing city #484 | ishigaki
# Processing city #485 | allada
# Processing city #486 | jinka
# Processing city #487 | rzhyshchiv
# Processing city #488 | ejea de los caballeros
# Processing city #489 | berlevag
# Processing city #490 | hihifo
# City not found hihifo
# Processing city #491 | amurzet
# Processing city #492 | toamasina
# Processing city #493 | radyvyliv
# Processing city #494 | iquique
# Processing city #495 | glendive
# Processing city #496 | nuevo progreso
# Processing city #497 | barabinsk
# Processing city #498 | dingle
# Processing city #499 | bojnurd
# Processing city #500 | broken hill
# Processing city #501 | agnibilekrou
# Processing city #502 | hami
# Processing city #503 | filadelfia
# Processing city #504 | muisne
# Processing city #505 | port blair
# Processing city #506 | gambo
# Processing city #507 | baijiantan
# Processing city #508 | narsaq
# Processing city #509 | uppsala
# Processing city #510 | dalvik
# Processing city #511 | mananara
# City not found mananara
# Processing city #512 | matagami
# Processing city #513 | tabou
# Processing city #514 | cayenne
# Processing city #515 | troitskoye
# Processing city #516 | batsfjord
# Processing city #517 | urusha
# Processing city #518 | buraydah
# Processing city #519 | north bend
# Processing city #520 | cururupu
# Processing city #521 | baykit
# Processing city #522 | chumikan
# Processing city #523 | brae
# Processing city #524 | uribia
# Processing city #525 | honjo
# Processing city #526 | karlshamn
# Processing city #527 | maningrida
# Processing city #528 | darhan
# Processing city #529 | camacupa
# Processing city #530 | high level
# Processing city #531 | cervo
# Processing city #532 | umzimvubu
# City not found umzimvubu
# Processing city #533 | forestville
# Processing city #534 | pangai
# Processing city #535 | kattivakkam
# Processing city #536 | elizabeth city
# Processing city #537 | shitkino
# Processing city #538 | san quintin
# Processing city #539 | meulaboh
# Processing city #540 | banikoara
# Processing city #541 | karasjok
# Processing city #542 | isabela
# Processing city #543 | rabat
# Processing city #544 | balkanabat
# Processing city #545 | sahuaripa
# Processing city #546 | smithers
# Processing city #547 | shingu
# Processing city #548 | khonuu
# City not found khonuu
# Processing city #549 | beloha
# Processing city #550 | guamuchil
# Processing city #551 | chapais
# Processing city #552 | dolakovo
# Processing city #553 | tooele
# Processing city #554 | nkayi
# Processing city #555 | puerto ayacucho
# Processing city #556 | chaman
# Processing city #557 | maragogi
# Processing city #558 | vrangel
# Processing city #559 | port hardy
# Processing city #560 | buta
# Processing city #561 | neya
# Processing city #562 | mangan
# Processing city #563 | creazzo
# Processing city #564 | fevralsk
# City not found fevralsk
# Processing city #565 | labuan
# Processing city #566 | rawson
# Processing city #567 | hobyo
# Processing city #568 | richards bay
# Processing city #569 | surgana
# Processing city #570 | juneau
# Processing city #571 | mecca
# Processing city #572 | cosala
# City not found cosala
# Processing city #573 | zephyrhills
# Processing city #574 | les cayes
# Processing city #575 | kitob
# Processing city #576 | aybak
# City not found aybak
# Processing city #577 | komsomolskiy
# Processing city #578 | utiroa
# City not found utiroa
# Processing city #579 | saint-pierre
# Processing city #580 | youghal
# Processing city #581 | clinton
# Processing city #582 | warmbad
# Processing city #583 | timaru
# Processing city #584 | manuk mangkaw
# Processing city #585 | hervey bay
# Processing city #586 | mumford
# Processing city #587 | vila velha
# Processing city #588 | adrar
# Processing city #589 | marsa matruh
# Processing city #590 | kawana waters
# City not found kawana waters
# Processing city #591 | eyl
# Processing city #592 | khandyga
# Processing city #593 | lobito
# Processing city #594 | alofi
# Processing city #595 | bissau
# Processing city #596 | nola
# Processing city #597 | troitsk
# Processing city #598 | werda
# Processing city #599 | wylie
# Processing city #600 | canby
# Processing city #601 | cockburn town
# Processing city #602 | kamenka
# Processing city #603 | costa rica
# Processing city #604 | sarkikaraagac
# Processing city #605 | japura
# Processing city #606 | lushunkou
# City not found lushunkou
# Processing city #607 | xuddur
# Processing city #608 | lanas
# Processing city #609 | ishim
# Processing city #610 | mackay
# Processing city #611 | svetlogorsk
# Processing city #612 | kuytun
# Processing city #613 | bolshevik
# Processing city #614 | sinfra
# Processing city #615 | iquitos
# Processing city #616 | abu samrah
# Processing city #617 | lolua
# City not found lolua
# Processing city #618 | okha
# Processing city #619 | istok
# Processing city #620 | the valley
# Processing city #621 | pringsewu
# Processing city #622 | zhanaozen
# Processing city #623 | kiruna
# Processing city #624 | luau
# Processing city #625 | alabaster
# Processing city #626 | sambava
# Processing city #627 | saint-joseph
# Processing city #628 | moscavide
# Processing city #629 | pingshan
# Processing city #630 | nampula
# Processing city #631 | kerman
# Processing city #632 | sataua
# City not found sataua
# Processing city #633 | ketchikan
# Processing city #634 | la asuncion
# Processing city #635 | chaohu
# Processing city #636 | gold coast
# Processing city #637 | fauske
# Processing city #638 | banmo
# City not found banmo
# Processing city #639 | hualmay
# Processing city #640 | abrau-dyurso
# Processing city #641 | mao
# Processing city #642 | athikia
# Processing city #643 | llangefni
# Processing city #644 | alpena
# Processing city #645 | ardino
# Processing city #646 | manzanillo
# Processing city #647 | maraa
# Processing city #648 | caramoran
# Processing city #649 | ilka
# City not found ilka
# Processing city #650 | ballina
# Processing city #651 | turka
# Processing city #652 | te anau
# --- Data Retrieval Complete ---

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dictionary_list
# Out:
# [{'City': 'Rikitea',
#   'Cloudiness': 36,
#   'Country': 'PF',
#   'Date': 1566566585,
#   'Humidity': 72,
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 70.02,
#   'Wind Speed': 13.94},
#  {'City': 'Tasiilaq',
#   'Cloudiness': 40,
#   'Country': 'GL',
#   'Date': 1566566912,
#   'Humidity': 75,
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 42.8,
#   'Wind Speed': 2.24},
#  {'City': 'Mataura',
#   'Cloudiness': 91,
#   'Country': 'NZ',
#   'Date': 1566566853,
#   'Humidity': 81,
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 44.01,
#   'Wind Speed': 4},
#  {'City': 'Jalu',
#   'Cloudiness': 0,
#   'Country': 'LY',
#   'Date': 1566567200,
#   'Humidity': 16,
#   'Lat': 29.03,
#   'Lng': 21.55,
#   'Max Temp': 100.36,
#   'Wind Speed': 12.12},
#  {'City': 'Hobart',
#   'Cloudiness': 20,
#   'Country': 'AU',
#   'Date': 1566566782,
#   'Humidity': 57,
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 51.8,
#   'Wind Speed': 14.99},
#  {'City': 'Le Mars',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567131,
#   'Humidity': 77,
#   'Lat': 42.79,
#   'Lng': -96.17,
#   'Max Temp': 64,
#   'Wind Speed': 8.05},
#  {'City': 'Bluff',
#   'Cloudiness': 73,
#   'Country': 'AU',
#   'Date': 1566566876,
#   'Humidity': 78,
#   'Lat': -23.58,
#   'Lng': 149.07,
#   'Max Temp': 59.04,
#   'Wind Speed': 13.76},
#  {'City': 'Airai',
#   'Cloudiness': 0,
#   'Country': 'TL',
#   'Date': 1566567204,
#   'Humidity': 87,
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 69.22,
#   'Wind Speed': 3.98},
#  {'City': 'Butaritari',
#   'Cloudiness': 59,
#   'Country': 'KI',
#   'Date': 1566566870,
#   'Humidity': 72,
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 84.24,
#   'Wind Speed': 12.28},
#  {'City': 'Busselton',
#   'Cloudiness': 17,
#   'Country': 'AU',
#   'Date': 1566566848,
#   'Humidity': 59,
#   'Lat': -33.64,
#   'Lng': 115.35,
#   'Max Temp': 44.01,
#   'Wind Speed': 17.07},
#  {'City': 'Zhangye',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1566567207,
#   'Humidity': 46,
#   'Lat': 38.94,
#   'Lng': 100.46,
#   'Max Temp': 63.82,
#   'Wind Speed': 3.38},
#  {'City': 'Ushuaia',
#   'Cloudiness': 75,
#   'Country': 'AR',
#   'Date': 1566566746,
#   'Humidity': 75,
#   'Lat': -54.81,
#   'Lng': -68.31,
#   'Max Temp': 41,
#   'Wind Speed': 6.93},
#  {'City': 'Caravelas',
#   'Cloudiness': 48,
#   'Country': 'BR',
#   'Date': 1566567212,
#   'Humidity': 62,
#   'Lat': -17.73,
#   'Lng': -39.27,
#   'Max Temp': 74.26,
#   'Wind Speed': 7.18},
#  {'City': 'Port Elizabeth',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1566566875,
#   'Humidity': 88,
#   'Lat': 39.31,
#   'Lng': -74.98,
#   'Max Temp': 77,
#   'Wind Speed': 10.29},
#  {'City': 'New Norfolk',
#   'Cloudiness': 20,
#   'Country': 'AU',
#   'Date': 1566566866,
#   'Humidity': 57,
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 51.8,
#   'Wind Speed': 14.99},
#  {'City': 'Hermanus',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1566566751,
#   'Humidity': 77,
#   'Lat': -34.42,
#   'Lng': 19.24,
#   'Max Temp': 61.2,
#   'Wind Speed': 10.92},
#  {'City': 'Ribeira Grande',
#   'Cloudiness': 40,
#   'Country': 'PT',
#   'Date': 1566566865,
#   'Humidity': 78,
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 77,
#   'Wind Speed': 10.29},
#  {'City': 'Nantucket',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1566567064,
#   'Humidity': 64,
#   'Lat': 41.28,
#   'Lng': -70.1,
#   'Max Temp': 75.2,
#   'Wind Speed': 9.17},
#  {'City': 'Aller',
#   'Cloudiness': 20,
#   'Country': 'GB',
#   'Date': 1566567220,
#   'Humidity': 47,
#   'Lat': 51.06,
#   'Lng': -2.86,
#   'Max Temp': 77,
#   'Wind Speed': 8.05},
#  {'City': 'Montepuez',
#   'Cloudiness': 4,
#   'Country': 'MZ',
#   'Date': 1566567221,
#   'Humidity': 37,
#   'Lat': -13.13,
#   'Lng': 39,
#   'Max Temp': 80.02,
#   'Wind Speed': 6.06},
#  {'City': 'Dubbo',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1566567224,
#   'Humidity': 55,
#   'Lat': -32.25,
#   'Lng': 148.6,
#   'Max Temp': 39.2,
#   'Wind Speed': 5.82},
#  {'City': 'Bredasdorp',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1566566852,
#   'Humidity': 60,
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 68,
#   'Wind Speed': 5.82},
#  {'City': 'Thunder Bay',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1566567226,
#   'Humidity': 93,
#   'Lat': 48.41,
#   'Lng': -89.26,
#   'Max Temp': 57,
#   'Wind Speed': 5.82},
#  {'City': 'Itarema',
#   'Cloudiness': 54,
#   'Country': 'BR',
#   'Date': 1566566888,
#   'Humidity': 51,
#   'Lat': -2.92,
#   'Lng': -39.92,
#   'Max Temp': 84.42,
#   'Wind Speed': 11.52},
#  {'City': 'Aleksandrov Gay',
#   'Cloudiness': 90,
#   'Country': 'RU',
#   'Date': 1566567228,
#   'Humidity': 28,
#   'Lat': 50.14,
#   'Lng': 48.57,
#   'Max Temp': 87.04,
#   'Wind Speed': 9.01},
#  {'City': 'Chokurdakh',
#   'Cloudiness': 91,
#   'Country': 'RU',
#   'Date': 1566566847,
#   'Humidity': 67,
#   'Lat': 70.62,
#   'Lng': 147.9,
#   'Max Temp': 53.46,
#   'Wind Speed': 5.48},
#  {'City': 'Victoria',
#   'Cloudiness': 75,
#   'Country': 'BN',
#   'Date': 1566566884,
#   'Humidity': 83,
#   'Lat': 5.28,
#   'Lng': 115.24,
#   'Max Temp': 84.2,
#   'Wind Speed': 9.1},
#  {'City': 'Havelock',
#   'Cloudiness': 20,
#   'Country': 'US',
#   'Date': 1566567231,
#   'Humidity': 74,
#   'Lat': 34.88,
#   'Lng': -76.9,
#   'Max Temp': 87.01,
#   'Wind Speed': 13.87},
#  {'City': 'Staryy Nadym',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566566859,
#   'Humidity': 64,
#   'Lat': 65.61,
#   'Lng': 72.68,
#   'Max Temp': 60.12,
#   'Wind Speed': 5.19},
#  {'City': 'Dunedin',
#   'Cloudiness': 90,
#   'Country': 'NZ',
#   'Date': 1566567204,
#   'Humidity': 75,
#   'Lat': -45.87,
#   'Lng': 170.5,
#   'Max Temp': 46.99,
#   'Wind Speed': 13},
#  {'City': 'Visnes',
#   'Cloudiness': 75,
#   'Country': 'NO',
#   'Date': 1566567235,
#   'Humidity': 72,
#   'Lat': 59.36,
#   'Lng': 5.22,
#   'Max Temp': 64.4,
#   'Wind Speed': 9.17},
#  {'City': 'Jamestown',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1566566626,
#   'Humidity': 50,
#   'Lat': -33.21,
#   'Lng': 138.6,
#   'Max Temp': 51.3,
#   'Wind Speed': 10.96},
#  {'City': 'Hovd',
#   'Cloudiness': 40,
#   'Country': 'NO',
#   'Date': 1566567237,
#   'Humidity': 67,
#   'Lat': 63.83,
#   'Lng': 10.7,
#   'Max Temp': 63,
#   'Wind Speed': 12.75},
#  {'City': 'Albany',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1566566742,
#   'Humidity': 64,
#   'Lat': 42.65,
#   'Lng': -73.75,
#   'Max Temp': 69.01,
#   'Wind Speed': 3.89},
#  {'City': 'Guerrero Negro',
#   'Cloudiness': 0,
#   'Country': 'MX',
#   'Date': 1566566845,
#   'Humidity': 89,
#   'Lat': 27.97,
#   'Lng': -114.04,
#   'Max Temp': 66.42,
#   'Wind Speed': 3.13},
#  {'City': 'Murray Bridge',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1566567242,
#   'Humidity': 61,
#   'Lat': -35.12,
#   'Lng': 139.28,
#   'Max Temp': 57.99,
#   'Wind Speed': 1.01},
#  {'City': 'Piqua',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567244,
#   'Humidity': 82,
#   'Lat': 40.14,
#   'Lng': -84.24,
#   'Max Temp': 69.8,
#   'Wind Speed': 4.7},
#  {'City': 'Punta Arenas',
#   'Cloudiness': 90,
#   'Country': 'CL',
#   'Date': 1566566859,
#   'Humidity': 93,
#   'Lat': -53.16,
#   'Lng': -70.91,
#   'Max Temp': 39.2,
#   'Wind Speed': 13.87},
#  {'City': 'Vasilsursk',
#   'Cloudiness': 31,
#   'Country': 'RU',
#   'Date': 1566567247,
#   'Humidity': 70,
#   'Lat': 56.13,
#   'Lng': 46.01,
#   'Max Temp': 65.8,
#   'Wind Speed': 4.07},
#  {'City': 'East London',
#   'Cloudiness': 40,
#   'Country': 'ZA',
#   'Date': 1566566876,
#   'Humidity': 72,
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 68,
#   'Wind Speed': 10.29},
#  {'City': 'Port Alfred',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1566566873,
#   'Humidity': 82,
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 66.99,
#   'Wind Speed': 5.01},
#  {'City': 'Mandalgovi',
#   'Cloudiness': 97,
#   'Country': 'MN',
#   'Date': 1566567250,
#   'Humidity': 61,
#   'Lat': 45.76,
#   'Lng': 106.27,
#   'Max Temp': 60.76,
#   'Wind Speed': 13.22},
#  {'City': 'Thompson',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1566566689,
#   'Humidity': 93,
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 46.4,
#   'Wind Speed': 2.24},
#  {'City': 'Cape Town',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1566566706,
#   'Humidity': 36,
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 75.2,
#   'Wind Speed': 4.7},
#  {'City': 'Kirakira',
#   'Cloudiness': 100,
#   'Country': 'SB',
#   'Date': 1566567253,
#   'Humidity': 90,
#   'Lat': -10.46,
#   'Lng': 161.92,
#   'Max Temp': 77.32,
#   'Wind Speed': 14.45},
#  {'City': 'Natal',
#   'Cloudiness': 40,
#   'Country': 'BR',
#   'Date': 1566567254,
#   'Humidity': 51,
#   'Lat': -5.81,
#   'Lng': -35.21,
#   'Max Temp': 84.2,
#   'Wind Speed': 20.8},
#  {'City': 'Manga',
#   'Cloudiness': 36,
#   'Country': 'PK',
#   'Date': 1566567256,
#   'Humidity': 37,
#   'Lat': 31.31,
#   'Lng': 74.05,
#   'Max Temp': 94.78,
#   'Wind Speed': 7.61},
#  {'City': 'Pangnirtung',
#   'Cloudiness': 40,
#   'Country': 'CA',
#   'Date': 1566567257,
#   'Humidity': 87,
#   'Lat': 66.15,
#   'Lng': -65.72,
#   'Max Temp': 46.4,
#   'Wind Speed': 5.82},
#  {'City': 'Jodhpur',
#   'Cloudiness': 53,
#   'Country': 'IN',
#   'Date': 1566567258,
#   'Humidity': 41,
#   'Lat': 26.3,
#   'Lng': 73.04,
#   'Max Temp': 91.72,
#   'Wind Speed': 14.03},
#  {'City': 'Takoradi',
#   'Cloudiness': 56,
#   'Country': 'GH',
#   'Date': 1566567259,
#   'Humidity': 61,
#   'Lat': 4.89,
#   'Lng': -1.75,
#   'Max Temp': 84.16,
#   'Wind Speed': 11.52},
#  {'City': 'Luderitz',
#   'Cloudiness': 0,
#   'Country': 'NA',
#   'Date': 1566566862,
#   'Humidity': 35,
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 95,
#   'Wind Speed': 13.87},
#  {'City': 'Sept-Iles',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1566566988,
#   'Humidity': 82,
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 60.01,
#   'Wind Speed': 6.93},
#  {'City': 'Basco',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566566843,
#   'Humidity': 88,
#   'Lat': 40.33,
#   'Lng': -91.2,
#   'Max Temp': 66,
#   'Wind Speed': 6.93},
#  {'City': 'Ancud',
#   'Cloudiness': 90,
#   'Country': 'CL',
#   'Date': 1566567266,
#   'Humidity': 100,
#   'Lat': -41.87,
#   'Lng': -73.83,
#   'Max Temp': 44.6,
#   'Wind Speed': 6.93},
#  {'City': 'Chabahar',
#   'Cloudiness': 2,
#   'Country': 'IR',
#   'Date': 1566567267,
#   'Humidity': 79,
#   'Lat': 25.29,
#   'Lng': 60.65,
#   'Max Temp': 81.28,
#   'Wind Speed': 6.35},
#  {'City': 'Castro',
#   'Cloudiness': 90,
#   'Country': 'CL',
#   'Date': 1566566889,
#   'Humidity': 100,
#   'Lat': -42.48,
#   'Lng': -73.76,
#   'Max Temp': 44.6,
#   'Wind Speed': 6.93},
#  {'City': 'Ponta do Sol',
#   'Cloudiness': 6,
#   'Country': 'BR',
#   'Date': 1566566881,
#   'Humidity': 65,
#   'Lat': -20.63,
#   'Lng': -46,
#   'Max Temp': 68.22,
#   'Wind Speed': 0.04},
#  {'City': 'Husavik',
#   'Cloudiness': 38,
#   'Country': 'CA',
#   'Date': 1566566860,
#   'Humidity': 75,
#   'Lat': 50.56,
#   'Lng': -96.99,
#   'Max Temp': 57,
#   'Wind Speed': 3},
#  {'City': 'Sisimiut',
#   'Cloudiness': 1,
#   'Country': 'GL',
#   'Date': 1566567271,
#   'Humidity': 83,
#   'Lat': 66.94,
#   'Lng': -53.67,
#   'Max Temp': 42.4,
#   'Wind Speed': 12.55},
#  {'City': 'Banda Aceh',
#   'Cloudiness': 100,
#   'Country': 'ID',
#   'Date': 1566567273,
#   'Humidity': 77,
#   'Lat': 5.56,
#   'Lng': 95.32,
#   'Max Temp': 83.26,
#   'Wind Speed': 15.97},
#  {'City': 'Nikolskoye',
#   'Cloudiness': 75,
#   'Country': 'RU',
#   'Date': 1566566846,
#   'Humidity': 46,
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 69.8,
#   'Wind Speed': 15.66},
#  {'City': 'Tromso',
#   'Cloudiness': 20,
#   'Country': 'NO',
#   'Date': 1566567275,
#   'Humidity': 76,
#   'Lat': 69.65,
#   'Lng': 18.96,
#   'Max Temp': 60.8,
#   'Wind Speed': 4.7},
#  {'City': 'Esperance',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': 1566567277,
#   'Humidity': 100,
#   'Lat': -33.86,
#   'Lng': 121.89,
#   'Max Temp': 48.2,
#   'Wind Speed': 2.24},
#  {'City': 'Barrow',
#   'Cloudiness': 99,
#   'Country': 'AR',
#   'Date': 1566566849,
#   'Humidity': 69,
#   'Lat': -38.31,
#   'Lng': -60.23,
#   'Max Temp': 46.98,
#   'Wind Speed': 6.04},
#  {'City': 'Cidreira',
#   'Cloudiness': 54,
#   'Country': 'BR',
#   'Date': 1566567279,
#   'Humidity': 61,
#   'Lat': -30.17,
#   'Lng': -50.22,
#   'Max Temp': 62.74,
#   'Wind Speed': 10.58},
#  {'City': 'Fare',
#   'Cloudiness': 50,
#   'Country': 'PF',
#   'Date': 1566567280,
#   'Humidity': 75,
#   'Lat': -16.7,
#   'Lng': -151.02,
#   'Max Temp': 77.14,
#   'Wind Speed': 12.3},
#  {'City': 'Hastings',
#   'Cloudiness': 99,
#   'Country': 'NZ',
#   'Date': 1566567281,
#   'Humidity': 93,
#   'Lat': -39.64,
#   'Lng': 176.84,
#   'Max Temp': 41.68,
#   'Wind Speed': 8.79},
#  {'City': 'Beringovskiy',
#   'Cloudiness': 48,
#   'Country': 'RU',
#   'Date': 1566567283,
#   'Humidity': 84,
#   'Lat': 63.05,
#   'Lng': 179.32,
#   'Max Temp': 40.06,
#   'Wind Speed': 2.66},
#  {'City': 'Miri',
#   'Cloudiness': 100,
#   'Country': 'NG',
#   'Date': 1566567284,
#   'Humidity': 52,
#   'Lat': 10.31,
#   'Lng': 9.75,
#   'Max Temp': 85.96,
#   'Wind Speed': 1.32},
#  {'City': 'Saldanha',
#   'Cloudiness': 0,
#   'Country': 'PT',
#   'Date': 1566566902,
#   'Humidity': 16,
#   'Lat': 41.42,
#   'Lng': -6.55,
#   'Max Temp': 90.72,
#   'Wind Speed': 4.09},
#  {'City': 'Kavieng',
#   'Cloudiness': 100,
#   'Country': 'PG',
#   'Date': 1566566905,
#   'Humidity': 76,
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 82.98,
#   'Wind Speed': 10.96},
#  {'City': 'Ahuimanu',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1566567287,
#   'Humidity': 83,
#   'Lat': 21.44,
#   'Lng': -157.84,
#   'Max Temp': 81,
#   'Wind Speed': 3.36},
#  {'City': 'Vestmanna',
#   'Cloudiness': 90,
#   'Country': 'FO',
#   'Date': 1566567288,
#   'Humidity': 82,
#   'Lat': 62.16,
#   'Lng': -7.17,
#   'Max Temp': 55.4,
#   'Wind Speed': 13.87},
#  {'City': 'Khash',
#   'Cloudiness': 0,
#   'Country': 'IR',
#   'Date': 1566567290,
#   'Humidity': 14,
#   'Lat': 28.22,
#   'Lng': 61.21,
#   'Max Temp': 72.28,
#   'Wind Speed': 12.39},
#  {'City': 'Merzifon',
#   'Cloudiness': 75,
#   'Country': 'TR',
#   'Date': 1566567291,
#   'Humidity': 45,
#   'Lat': 40.87,
#   'Lng': 35.46,
#   'Max Temp': 82.4,
#   'Wind Speed': 10.29},
#  {'City': 'Norfolk',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567006,
#   'Humidity': 78,
#   'Lat': 36.85,
#   'Lng': -76.29,
#   'Max Temp': 82.4,
#   'Wind Speed': 7.2},
#  {'City': 'Vao',
#   'Cloudiness': 100,
#   'Country': 'EE',
#   'Date': 1566567293,
#   'Humidity': 91,
#   'Lat': 59.1,
#   'Lng': 26.19,
#   'Max Temp': 59.68,
#   'Wind Speed': 12.5},
#  {'City': 'Svetlaya',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567294,
#   'Humidity': 98,
#   'Lat': 46.54,
#   'Lng': 138.33,
#   'Max Temp': 48.34,
#   'Wind Speed': 6.13},
#  {'City': 'Pangoa',
#   'Cloudiness': 0,
#   'Country': 'PE',
#   'Date': 1566567296,
#   'Humidity': 37,
#   'Lat': -12.12,
#   'Lng': -73,
#   'Max Temp': 89.56,
#   'Wind Speed': 1.03},
#  {'City': 'Kiama',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1566567297,
#   'Humidity': 45,
#   'Lat': -34.67,
#   'Lng': 150.86,
#   'Max Temp': 53.01,
#   'Wind Speed': 10.29},
#  {'City': 'Santiago del Estero',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': 1566567228,
#   'Humidity': 36,
#   'Lat': -27.8,
#   'Lng': -64.26,
#   'Max Temp': 69.04,
#   'Wind Speed': 13.76},
#  {'City': 'Nemuro',
#   'Cloudiness': 100,
#   'Country': 'JP',
#   'Date': 1566567299,
#   'Humidity': 96,
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 60.94,
#   'Wind Speed': 29.62},
#  {'City': 'Kalmunai',
#   'Cloudiness': 100,
#   'Country': 'LK',
#   'Date': 1566567301,
#   'Humidity': 56,
#   'Lat': 7.42,
#   'Lng': 81.82,
#   'Max Temp': 81.46,
#   'Wind Speed': 0.51},
#  {'City': 'Hithadhoo',
#   'Cloudiness': 77,
#   'Country': 'MV',
#   'Date': 1566566864,
#   'Humidity': 67,
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 83.88,
#   'Wind Speed': 6.33},
#  {'City': 'Avarua',
#   'Cloudiness': 0,
#   'Country': 'CK',
#   'Date': 1566566737,
#   'Humidity': 73,
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 73.4,
#   'Wind Speed': 10.29},
#  {'City': 'Barlinek',
#   'Cloudiness': 0,
#   'Country': 'PL',
#   'Date': 1566567304,
#   'Humidity': 34,
#   'Lat': 53,
#   'Lng': 15.22,
#   'Max Temp': 80.01,
#   'Wind Speed': 12.75},
#  {'City': 'Santa Fe',
#   'Cloudiness': 97,
#   'Country': 'AR',
#   'Date': 1566567177,
#   'Humidity': 63,
#   'Lat': -31.62,
#   'Lng': -60.7,
#   'Max Temp': 60.01,
#   'Wind Speed': 1.99},
#  {'City': 'Faya',
#   'Cloudiness': 40,
#   'Country': 'SA',
#   'Date': 1566566907,
#   'Humidity': 50,
#   'Lat': 18.39,
#   'Lng': 42.45,
#   'Max Temp': 84.2,
#   'Wind Speed': 11.41},
#  {'City': 'Ovalle',
#   'Cloudiness': 24,
#   'Country': 'CL',
#   'Date': 1566567310,
#   'Humidity': 29,
#   'Lat': -30.6,
#   'Lng': -71.2,
#   'Max Temp': 72.64,
#   'Wind Speed': 3.89},
#  {'City': 'Lagoa',
#   'Cloudiness': 0,
#   'Country': 'PT',
#   'Date': 1566566862,
#   'Humidity': 45,
#   'Lat': 37.14,
#   'Lng': -8.45,
#   'Max Temp': 91.99,
#   'Wind Speed': 12.75},
#  {'City': 'Grande-Synthe',
#   'Cloudiness': 0,
#   'Country': 'FR',
#   'Date': 1566567313,
#   'Humidity': 64,
#   'Lat': 51.01,
#   'Lng': 2.3,
#   'Max Temp': 86,
#   'Wind Speed': 11.41},
#  {'City': 'Kapaa',
#   'Cloudiness': 20,
#   'Country': 'US',
#   'Date': 1566567315,
#   'Humidity': 78,
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 80.6,
#   'Wind Speed': 9.17},
#  {'City': 'Kidal',
#   'Cloudiness': 47,
#   'Country': 'ML',
#   'Date': 1566567316,
#   'Humidity': 33,
#   'Lat': 18.44,
#   'Lng': 1.41,
#   'Max Temp': 95.14,
#   'Wind Speed': 12.95},
#  {'City': 'Phan Thiet',
#   'Cloudiness': 100,
#   'Country': 'VN',
#   'Date': 1566567193,
#   'Humidity': 84,
#   'Lat': 10.93,
#   'Lng': 108.1,
#   'Max Temp': 77.32,
#   'Wind Speed': 5.84},
#  {'City': 'Sitka',
#   'Cloudiness': 100,
#   'Country': 'US',
#   'Date': 1566567318,
#   'Humidity': 96,
#   'Lat': 37.17,
#   'Lng': -99.65,
#   'Max Temp': 68,
#   'Wind Speed': 11.99},
#  {'City': 'Upernavik',
#   'Cloudiness': 0,
#   'Country': 'GL',
#   'Date': 1566566846,
#   'Humidity': 55,
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 37.08,
#   'Wind Speed': 10.38},
#  {'City': 'Saint George',
#   'Cloudiness': 20,
#   'Country': 'GR',
#   'Date': 1566566915,
#   'Humidity': 26,
#   'Lat': 39.45,
#   'Lng': 22.34,
#   'Max Temp': 95,
#   'Wind Speed': 17.22},
#  {'City': 'Isangel',
#   'Cloudiness': 31,
#   'Country': 'VU',
#   'Date': 1566566847,
#   'Humidity': 94,
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 71.6,
#   'Wind Speed': 12.75},
#  {'City': 'Huarmey',
#   'Cloudiness': 99,
#   'Country': 'PE',
#   'Date': 1566567323,
#   'Humidity': 91,
#   'Lat': -10.07,
#   'Lng': -78.15,
#   'Max Temp': 59.32,
#   'Wind Speed': 10.96},
#  {'City': 'Shubarshi',
#   'Cloudiness': 0,
#   'Country': 'KZ',
#   'Date': 1566567324,
#   'Humidity': 23,
#   'Lat': 48.59,
#   'Lng': 57.19,
#   'Max Temp': 79.66,
#   'Wind Speed': 3.33},
#  {'City': 'Nieuw Amsterdam',
#   'Cloudiness': 40,
#   'Country': 'SR',
#   'Date': 1566567325,
#   'Humidity': 70,
#   'Lat': 5.88,
#   'Lng': -55.08,
#   'Max Temp': 86,
#   'Wind Speed': 8.05},
#  {'City': 'Sardinia',
#   'Cloudiness': 20,
#   'Country': 'GR',
#   'Date': 1566567326,
#   'Humidity': 41,
#   'Lat': 38.89,
#   'Lng': 21.2,
#   'Max Temp': 91.4,
#   'Wind Speed': 13.87},
#  {'City': 'Saint-Philippe',
#   'Cloudiness': 1,
#   'Country': 'CA',
#   'Date': 1566566877,
#   'Humidity': 63,
#   'Lat': 45.36,
#   'Lng': -73.48,
#   'Max Temp': 64.99,
#   'Wind Speed': 8.05},
#  {'City': 'Inuvik',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1566567330,
#   'Humidity': 93,
#   'Lat': 68.36,
#   'Lng': -133.71,
#   'Max Temp': 41,
#   'Wind Speed': 2.24},
#  {'City': 'Fortuna',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1566566889,
#   'Humidity': 100,
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 55,
#   'Wind Speed': 18.1},
#  {'City': 'Eenhana',
#   'Cloudiness': 0,
#   'Country': 'NA',
#   'Date': 1566567332,
#   'Humidity': 8,
#   'Lat': -17.48,
#   'Lng': 16.34,
#   'Max Temp': 84.2,
#   'Wind Speed': 14.99},
#  {'City': 'Avera',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567334,
#   'Humidity': 83,
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Max Temp': 84,
#   'Wind Speed': 3.06},
#  {'City': 'Provideniya',
#   'Cloudiness': 56,
#   'Country': 'RU',
#   'Date': 1566566745,
#   'Humidity': 78,
#   'Lat': 64.42,
#   'Lng': -173.23,
#   'Max Temp': 41.04,
#   'Wind Speed': 8.79},
#  {'City': 'Atar',
#   'Cloudiness': 0,
#   'Country': 'MR',
#   'Date': 1566567336,
#   'Humidity': 20,
#   'Lat': 20.52,
#   'Lng': -13.05,
#   'Max Temp': 96.8,
#   'Wind Speed': 13.87},
#  {'City': 'Siderno',
#   'Cloudiness': 20,
#   'Country': 'IT',
#   'Date': 1566567338,
#   'Humidity': 48,
#   'Lat': 38.28,
#   'Lng': 16.3,
#   'Max Temp': 89.01,
#   'Wind Speed': 10.29},
#  {'City': 'Samsun',
#   'Cloudiness': 75,
#   'Country': 'TR',
#   'Date': 1566567340,
#   'Humidity': 78,
#   'Lat': 41.29,
#   'Lng': 36.33,
#   'Max Temp': 71.6,
#   'Wind Speed': 2.24},
#  {'City': 'Tagusao',
#   'Cloudiness': 99,
#   'Country': 'PH',
#   'Date': 1566567341,
#   'Humidity': 81,
#   'Lat': 9.19,
#   'Lng': 117.81,
#   'Max Temp': 82.36,
#   'Wind Speed': 12.68},
#  {'City': 'Klaksvik',
#   'Cloudiness': 90,
#   'Country': 'FO',
#   'Date': 1566566868,
#   'Humidity': 82,
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 55.4,
#   'Wind Speed': 13.87},
#  {'City': 'Puerto Ayora',
#   'Cloudiness': 90,
#   'Country': 'EC',
#   'Date': 1566566901,
#   'Humidity': 77,
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 69.8,
#   'Wind Speed': 9.17},
#  {'City': 'Kedrovyy',
#   'Cloudiness': 75,
#   'Country': 'RU',
#   'Date': 1566567344,
#   'Humidity': 93,
#   'Lat': 56.17,
#   'Lng': 91.82,
#   'Max Temp': 57.2,
#   'Wind Speed': 8.95},
#  {'City': 'Qaanaaq',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': 1566566848,
#   'Humidity': 62,
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 30.96,
#   'Wind Speed': 19.19},
#  {'City': 'Bethel',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566566887,
#   'Humidity': 100,
#   'Lat': 60.79,
#   'Lng': -161.76,
#   'Max Temp': 50,
#   'Wind Speed': 4.29},
#  {'City': 'Hasaki',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1566566902,
#   'Humidity': 100,
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 77,
#   'Wind Speed': 5.48},
#  {'City': 'Tuatapere',
#   'Cloudiness': 55,
#   'Country': 'NZ',
#   'Date': 1566567349,
#   'Humidity': 81,
#   'Lat': -46.13,
#   'Lng': 167.69,
#   'Max Temp': 44.01,
#   'Wind Speed': 3},
#  {'City': 'Fatehabad',
#   'Cloudiness': 40,
#   'Country': 'IN',
#   'Date': 1566567350,
#   'Humidity': 100,
#   'Lat': 27.03,
#   'Lng': 78.3,
#   'Max Temp': 86,
#   'Wind Speed': 2.24},
#  {'City': 'Lanzhou',
#   'Cloudiness': 90,
#   'Country': 'CN',
#   'Date': 1566567351,
#   'Humidity': 100,
#   'Lat': 36.06,
#   'Lng': 103.82,
#   'Max Temp': 59,
#   'Wind Speed': 2.24},
#  {'City': 'Mahebourg',
#   'Cloudiness': 75,
#   'Country': 'MU',
#   'Date': 1566566836,
#   'Humidity': 69,
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 75.2,
#   'Wind Speed': 6.93},
#  {'City': 'Mar del Plata',
#   'Cloudiness': 100,
#   'Country': 'AR',
#   'Date': 1566566845,
#   'Humidity': 87,
#   'Lat': -46.43,
#   'Lng': -67.52,
#   'Max Temp': 40.68,
#   'Wind Speed': 21.99},
#  {'City': 'Morondava',
#   'Cloudiness': 100,
#   'Country': 'MG',
#   'Date': 1566567356,
#   'Humidity': 75,
#   'Lat': -20.3,
#   'Lng': 44.28,
#   'Max Temp': 77.14,
#   'Wind Speed': 7.67},
#  {'City': 'Severo-Kurilsk',
#   'Cloudiness': 87,
#   'Country': 'RU',
#   'Date': 1566567357,
#   'Humidity': 87,
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 48.88,
#   'Wind Speed': 6.06},
#  {'City': 'Gat',
#   'Cloudiness': 40,
#   'Country': 'SN',
#   'Date': 1566567359,
#   'Humidity': 74,
#   'Lat': 14.69,
#   'Lng': -16.54,
#   'Max Temp': 84.2,
#   'Wind Speed': 18.34},
#  {'City': 'Tabuk',
#   'Cloudiness': 100,
#   'Country': 'PH',
#   'Date': 1566567360,
#   'Humidity': 99,
#   'Lat': 17.41,
#   'Lng': 121.44,
#   'Max Temp': 66.34,
#   'Wind Speed': 4.63},
#  {'City': 'Nuqui',
#   'Cloudiness': 75,
#   'Country': 'CO',
#   'Date': 1566567361,
#   'Humidity': 100,
#   'Lat': 5.71,
#   'Lng': -77.27,
#   'Max Temp': 77,
#   'Wind Speed': 2.24},
#  {'City': 'Souillac',
#   'Cloudiness': 0,
#   'Country': 'FR',
#   'Date': 1566566873,
#   'Humidity': 25,
#   'Lat': 45.6,
#   'Lng': -0.6,
#   'Max Temp': 91,
#   'Wind Speed': 6.93},
#  {'City': 'Atuona',
#   'Cloudiness': 63,
#   'Country': 'PF',
#   'Date': 1566566857,
#   'Humidity': 74,
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 79.02,
#   'Wind Speed': 17.47},
#  {'City': 'Kruisfontein',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1566566887,
#   'Humidity': 48,
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 72.54,
#   'Wind Speed': 9.15},
#  {'City': 'Sarkand',
#   'Cloudiness': 69,
#   'Country': 'KZ',
#   'Date': 1566567368,
#   'Humidity': 33,
#   'Lat': 45.41,
#   'Lng': 79.91,
#   'Max Temp': 62.38,
#   'Wind Speed': 6.04},
#  {'City': 'Ures',
#   'Cloudiness': 0,
#   'Country': 'MX',
#   'Date': 1566567369,
#   'Humidity': 58,
#   'Lat': 30.73,
#   'Lng': -112.95,
#   'Max Temp': 82,
#   'Wind Speed': 8.99},
#  {'City': 'Ardmore',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567371,
#   'Humidity': 88,
#   'Lat': 34.99,
#   'Lng': -86.85,
#   'Max Temp': 81,
#   'Wind Speed': 3.36},
#  {'City': 'Faanui',
#   'Cloudiness': 73,
#   'Country': 'PF',
#   'Date': 1566566868,
#   'Humidity': 76,
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 77.4,
#   'Wind Speed': 13.06},
#  {'City': 'Nioki',
#   'Cloudiness': 100,
#   'Country': 'CD',
#   'Date': 1566567373,
#   'Humidity': 34,
#   'Lat': -2.72,
#   'Lng': 17.69,
#   'Max Temp': 92.62,
#   'Wind Speed': 1.52},
#  {'City': 'Port Hawkesbury',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1566567376,
#   'Humidity': 78,
#   'Lat': 45.62,
#   'Lng': -61.36,
#   'Max Temp': 78.01,
#   'Wind Speed': 9.17},
#  {'City': 'Cherskiy',
#   'Cloudiness': 48,
#   'Country': 'RU',
#   'Date': 1566566750,
#   'Humidity': 62,
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 50.04,
#   'Wind Speed': 4.9},
#  {'City': 'Aykhal',
#   'Cloudiness': 90,
#   'Country': 'RU',
#   'Date': 1566567378,
#   'Humidity': 100,
#   'Lat': 65.95,
#   'Lng': 111.51,
#   'Max Temp': 51.8,
#   'Wind Speed': 2.24},
#  {'City': 'Lerum',
#   'Cloudiness': 75,
#   'Country': 'SE',
#   'Date': 1566567379,
#   'Humidity': 88,
#   'Lat': 57.77,
#   'Lng': 12.27,
#   'Max Temp': 66.99,
#   'Wind Speed': 13.87},
#  {'City': 'Ngunguru',
#   'Cloudiness': 9,
#   'Country': 'NZ',
#   'Date': 1566567380,
#   'Humidity': 92,
#   'Lat': -35.62,
#   'Lng': 174.5,
#   'Max Temp': 48,
#   'Wind Speed': 5.01},
#  {'City': 'Hilo',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1566566850,
#   'Humidity': 64,
#   'Lat': 19.71,
#   'Lng': -155.08,
#   'Max Temp': 75.2,
#   'Wind Speed': 6.93},
#  {'City': 'Kodiak',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566566895,
#   'Humidity': 77,
#   'Lat': 39.95,
#   'Lng': -94.76,
#   'Max Temp': 69.8,
#   'Wind Speed': 5.82},
#  {'City': 'Vaini',
#   'Cloudiness': 90,
#   'Country': 'IN',
#   'Date': 1566566854,
#   'Humidity': 83,
#   'Lat': 15.34,
#   'Lng': 74.49,
#   'Max Temp': 78.8,
#   'Wind Speed': 10.29},
#  {'City': 'Kovdor',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567385,
#   'Humidity': 63,
#   'Lat': 67.56,
#   'Lng': 30.47,
#   'Max Temp': 56.62,
#   'Wind Speed': 2.95},
#  {'City': 'Hjelset',
#   'Cloudiness': 75,
#   'Country': 'NO',
#   'Date': 1566567386,
#   'Humidity': 82,
#   'Lat': 62.78,
#   'Lng': 7.5,
#   'Max Temp': 57.2,
#   'Wind Speed': 4.7},
#  {'City': 'Quatre Cocos',
#   'Cloudiness': 75,
#   'Country': 'MU',
#   'Date': 1566567387,
#   'Humidity': 69,
#   'Lat': -20.21,
#   'Lng': 57.76,
#   'Max Temp': 75.2,
#   'Wind Speed': 6.93},
#  {'City': 'Georgetown',
#   'Cloudiness': 75,
#   'Country': 'GY',
#   'Date': 1566566835,
#   'Humidity': 79,
#   'Lat': 6.8,
#   'Lng': -58.16,
#   'Max Temp': 84.2,
#   'Wind Speed': 2.24},
#  {'City': 'Macon',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': 1566567157,
#   'Humidity': 74,
#   'Lat': 32.84,
#   'Lng': -83.63,
#   'Max Temp': 84,
#   'Wind Speed': 3.36},
#  {'City': 'Necochea',
#   'Cloudiness': 97,
#   'Country': 'AR',
#   'Date': 1566567390,
#   'Humidity': 77,
#   'Lat': -38.55,
#   'Lng': -58.74,
#   'Max Temp': 51.01,
#   'Wind Speed': 1.99},
#  {'City': 'Vila do Maio',
#   'Cloudiness': 75,
#   'Country': 'CV',
#   'Date': 1566567392,
#   'Humidity': 69,
#   'Lat': 15.13,
#   'Lng': -23.22,
#   'Max Temp': 82.4,
#   'Wind Speed': 12.75},
#  {'City': 'Yangambi',
#   'Cloudiness': 73,
#   'Country': 'CD',
#   'Date': 1566567393,
#   'Humidity': 48,
#   'Lat': 0.77,
#   'Lng': 24.47,
#   'Max Temp': 89.02,
#   'Wind Speed': 2.53},
#  {'City': 'Pedernales',
#   'Cloudiness': 91,
#   'Country': 'EC',
#   'Date': 1566566851,
#   'Humidity': 88,
#   'Lat': 0.07,
#   'Lng': -80.05,
#   'Max Temp': 72.36,
#   'Wind Speed': 9.53},
#  {'City': 'Sorong',
#   'Cloudiness': 76,
#   'Country': 'ID',
#   'Date': 1566567396,
#   'Humidity': 94,
#   'Lat': -0.86,
#   'Lng': 131.25,
#   'Max Temp': 74.44,
#   'Wind Speed': 6.2},
#  {'City': 'Karratha',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1566567398,
#   'Humidity': 67,
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 64.9,
#   'Wind Speed': 7.47},
#  {'City': 'Tome',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1566567399,
#   'Humidity': 73,
#   'Lat': 38.69,
#   'Lng': 141.2,
#   'Max Temp': 75.2,
#   'Wind Speed': 2.24},
#  {'City': 'Clyde River',
#   'Cloudiness': 1,
#   'Country': 'CA',
#   'Date': 1566567400,
#   'Humidity': 81,
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 48.2,
#   'Wind Speed': 14.99},
#  {'City': 'High Prairie',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': 1566567401,
#   'Humidity': 76,
#   'Lat': 55.43,
#   'Lng': -116.48,
#   'Max Temp': 52.48,
#   'Wind Speed': 6.53},
#  {'City': 'Pemba',
#   'Cloudiness': 20,
#   'Country': 'MZ',
#   'Date': 1566567403,
#   'Humidity': 65,
#   'Lat': -12.97,
#   'Lng': 40.52,
#   'Max Temp': 78.8,
#   'Wind Speed': 20.8},
#  {'City': 'Xining',
#   'Cloudiness': 100,
#   'Country': 'CN',
#   'Date': 1566566914,
#   'Humidity': 94,
#   'Lat': 36.62,
#   'Lng': 101.77,
#   'Max Temp': 53.64,
#   'Wind Speed': 7.05},
#  {'City': 'Puerto Madryn',
#   'Cloudiness': 100,
#   'Country': 'AR',
#   'Date': 1566567405,
#   'Humidity': 32,
#   'Lat': -42.77,
#   'Lng': -65.04,
#   'Max Temp': 58.78,
#   'Wind Speed': 26.35},
#  {'City': 'Kavaratti',
#   'Cloudiness': 100,
#   'Country': 'IN',
#   'Date': 1566567406,
#   'Humidity': 78,
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 82.54,
#   'Wind Speed': 15.21},
#  {'City': 'Mangai',
#   'Cloudiness': 100,
#   'Country': 'CD',
#   'Date': 1566567409,
#   'Humidity': 31,
#   'Lat': -4.07,
#   'Lng': 19.59,
#   'Max Temp': 91.72,
#   'Wind Speed': 0.98},
#  {'City': 'Tsabong',
#   'Cloudiness': 0,
#   'Country': 'BW',
#   'Date': 1566567410,
#   'Humidity': 11,
#   'Lat': -26.02,
#   'Lng': 22.4,
#   'Max Temp': 80.38,
#   'Wind Speed': 4.79},
#  {'City': 'Yar-Sale',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567412,
#   'Humidity': 72,
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 56.44,
#   'Wind Speed': 5.14},
#  {'City': 'Bahia Honda',
#   'Cloudiness': 64,
#   'Country': 'CU',
#   'Date': 1566567414,
#   'Humidity': 73,
#   'Lat': 22.9,
#   'Lng': -83.16,
#   'Max Temp': 82.9,
#   'Wind Speed': 1.9},
#  {'City': 'Soyo',
#   'Cloudiness': 90,
#   'Country': 'AO',
#   'Date': 1566567415,
#   'Humidity': 82,
#   'Lat': -6.13,
#   'Lng': 12.37,
#   'Max Temp': 72.1,
#   'Wind Speed': 9.82},
#  {'City': 'Shimoda',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1566567416,
#   'Humidity': 83,
#   'Lat': 34.7,
#   'Lng': 138.93,
#   'Max Temp': 75.99,
#   'Wind Speed': 13.87},
#  {'City': 'Ibipeba',
#   'Cloudiness': 20,
#   'Country': 'BR',
#   'Date': 1566567418,
#   'Humidity': 39,
#   'Lat': -11.64,
#   'Lng': -42.01,
#   'Max Temp': 78.4,
#   'Wind Speed': 9.17},
#  {'City': 'Ilhabela',
#   'Cloudiness': 100,
#   'Country': 'BR',
#   'Date': 1566567264,
#   'Humidity': 83,
#   'Lat': -23.78,
#   'Lng': -45.36,
#   'Max Temp': 66.16,
#   'Wind Speed': 12.26},
#  {'City': 'Otradnoye',
#   'Cloudiness': 75,
#   'Country': 'RU',
#   'Date': 1566567420,
#   'Humidity': 46,
#   'Lat': 59.77,
#   'Lng': 30.8,
#   'Max Temp': 73,
#   'Wind Speed': 15.66},
#  {'City': 'Parrita',
#   'Cloudiness': 0,
#   'Country': 'CR',
#   'Date': 1566567421,
#   'Humidity': 73,
#   'Lat': 9.52,
#   'Lng': -84.33,
#   'Max Temp': 73.4,
#   'Wind Speed': 8.05},
#  {'City': 'Puerto Leguizamo',
#   'Cloudiness': 77,
#   'Country': 'CO',
#   'Date': 1566567423,
#   'Humidity': 72,
#   'Lat': -0.19,
#   'Lng': -74.78,
#   'Max Temp': 78.94,
#   'Wind Speed': 3.58},
#  {'City': 'Bilibino',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1566567424,
#   'Humidity': 75,
#   'Lat': 68.06,
#   'Lng': 166.44,
#   'Max Temp': 39.88,
#   'Wind Speed': 4.83},
#  {'City': 'Mount Isa',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1566567425,
#   'Humidity': 29,
#   'Lat': -20.73,
#   'Lng': 139.49,
#   'Max Temp': 51.8,
#   'Wind Speed': 3.36},
#  {'City': 'Constitucion',
#   'Cloudiness': 90,
#   'Country': 'MX',
#   'Date': 1566566845,
#   'Humidity': 82,
#   'Lat': 23.99,
#   'Lng': -104.67,
#   'Max Temp': 60.8,
#   'Wind Speed': 4.92},
#  {'City': 'Kaitangata',
#   'Cloudiness': 89,
#   'Country': 'NZ',
#   'Date': 1566566892,
#   'Humidity': 78,
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 44.01,
#   'Wind Speed': 1.99},
#  {'City': 'Vanimo',
#   'Cloudiness': 15,
#   'Country': 'PG',
#   'Date': 1566567430,
#   'Humidity': 71,
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 83.26,
#   'Wind Speed': 1.77},
#  {'City': 'Zvenigorod',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1566567431,
#   'Humidity': 43,
#   'Lat': 55.73,
#   'Lng': 36.86,
#   'Max Temp': 79,
#   'Wind Speed': 6.71},
#  {'City': 'Liuli',
#   'Cloudiness': 0,
#   'Country': 'TZ',
#   'Date': 1566567432,
#   'Humidity': 69,
#   'Lat': -11.1,
#   'Lng': 34.65,
#   'Max Temp': 73.72,
#   'Wind Speed': 16.6},
#  {'City': 'Whittlesea',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1566567434,
#   'Humidity': 61,
#   'Lat': -37.51,
#   'Lng': 145.12,
#   'Max Temp': 53.01,
#   'Wind Speed': 21.92},
#  {'City': 'Naze',
#   'Cloudiness': 100,
#   'Country': 'NG',
#   'Date': 1566566881,
#   'Humidity': 91,
#   'Lat': 5.43,
#   'Lng': 7.07,
#   'Max Temp': 74.52,
#   'Wind Speed': 5.37},
#  {'City': 'Rincon',
#   'Cloudiness': 20,
#   'Country': 'PA',
#   'Date': 1566567437,
#   'Humidity': 88,
#   'Lat': 8.46,
#   'Lng': -82.28,
#   'Max Temp': 77,
#   'Wind Speed': 3.36},
#  {'City': 'Taoudenni',
#   'Cloudiness': 20,
#   'Country': 'ML',
#   'Date': 1566567438,
#   'Humidity': 15,
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 109.9,
#   'Wind Speed': 9.01},
#  {'City': 'Vardo',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1566567439,
#   'Humidity': 93,
#   'Lat': 39.62,
#   'Lng': -77.74,
#   'Max Temp': 68,
#   'Wind Speed': 10.29},
#  {'City': 'Ginir',
#   'Cloudiness': 31,
#   'Country': 'ET',
#   'Date': 1566567441,
#   'Humidity': 73,
#   'Lat': 7.14,
#   'Lng': 40.71,
#   'Max Temp': 65.08,
#   'Wind Speed': 7.05},
#  {'City': 'Port Hedland',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1566567442,
#   'Humidity': 77,
#   'Lat': -20.31,
#   'Lng': 118.58,
#   'Max Temp': 62.6,
#   'Wind Speed': 8.63},
#  {'City': 'Kailua',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1566567443,
#   'Humidity': 83,
#   'Lat': 21.39,
#   'Lng': -157.74,
#   'Max Temp': 81,
#   'Wind Speed': 3.36},
#  {'City': 'Lufilufi',
#   'Cloudiness': 98,
#   'Country': 'WS',
#   'Date': 1566567444,
#   'Humidity': 75,
#   'Lat': -13.87,
#   'Lng': -171.6,
#   'Max Temp': 82.36,
#   'Wind Speed': 20.22},
#  {'City': 'Kristinehamn',
#   'Cloudiness': 75,
#   'Country': 'SE',
#   'Date': 1566567445,
#   'Humidity': 77,
#   'Lat': 59.31,
#   'Lng': 14.11,
#   'Max Temp': 68,
#   'Wind Speed': 17.22},
#  {'City': 'Punta Alta',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': 1566567447,
#   'Humidity': 77,
#   'Lat': -27.46,
#   'Lng': -55.82,
#   'Max Temp': 59,
#   'Wind Speed': 8.05},
#  {'City': 'Inirida',
#   'Cloudiness': 31,
#   'Country': 'CO',
#   'Date': 1566566870,
#   'Humidity': 98,
#   'Lat': 3.87,
#   'Lng': -67.92,
#   'Max Temp': 71.82,
#   'Wind Speed': 1.77},
#  {'City': 'Broome',
#   'Cloudiness': 20,
#   'Country': 'GB',
#   'Date': 1566567451,
#   'Humidity': 53,
#   'Lat': 52.47,
#   'Lng': 1.45,
#   'Max Temp': 82,
#   'Wind Speed': 4.7},
#  {'City': 'Kez',
#   'Cloudiness': 14,
#   'Country': 'RU',
#   'Date': 1566567452,
#   'Humidity': 73,
#   'Lat': 57.9,
#   'Lng': 53.72,
#   'Max Temp': 60.04,
#   'Wind Speed': 6.96},
#  {'City': 'Teya',
#   'Cloudiness': 40,
#   'Country': 'MX',
#   'Date': 1566567453,
#   'Humidity': 94,
#   'Lat': 21.05,
#   'Lng': -89.07,
#   'Max Temp': 82.99,
#   'Wind Speed': 6.93},
#  {'City': 'Nome',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': 1566567455,
#   'Humidity': 83,
#   'Lat': 30.04,
#   'Lng': -94.42,
#   'Max Temp': 82.4,
#   'Wind Speed': 3.36},
#  {'City': 'Tual',
#   'Cloudiness': 9,
#   'Country': 'ID',
#   'Date': 1566567456,
#   'Humidity': 87,
#   'Lat': -5.67,
#   'Lng': 132.75,
#   'Max Temp': 76.6,
#   'Wind Speed': 18.57},
#  {'City': 'Klobuck',
#   'Cloudiness': 20,
#   'Country': 'PL',
#   'Date': 1566567457,
#   'Humidity': 50,
#   'Lat': 50.9,
#   'Lng': 18.94,
#   'Max Temp': 78.01,
#   'Wind Speed': 9.17},
#  {'City': 'Mahajanga',
#   'Cloudiness': 40,
#   'Country': 'MG',
#   'Date': 1566566917,
#   'Humidity': 46,
#   'Lat': -15.72,
#   'Lng': 46.32,
#   'Max Temp': 89.6,
#   'Wind Speed': 11.41},
#  {'City': 'Kahului',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567429,
#   'Humidity': 73,
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 77,
#   'Wind Speed': 6.93},
#  {'City': 'San Mateo Ixtatan',
#   'Cloudiness': 0,
#   'Country': 'GT',
#   'Date': 1566567462,
#   'Humidity': 60,
#   'Lat': 15.83,
#   'Lng': -91.48,
#   'Max Temp': 73,
#   'Wind Speed': 3.33},
#  {'City': 'Carnarvon',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1566566795,
#   'Humidity': 14,
#   'Lat': -30.97,
#   'Lng': 22.13,
#   'Max Temp': 75.42,
#   'Wind Speed': 16.15},
#  {'City': 'Marrakesh',
#   'Cloudiness': 40,
#   'Country': 'MA',
#   'Date': 1566567464,
#   'Humidity': 11,
#   'Lat': 31.63,
#   'Lng': -7.99,
#   'Max Temp': 111.2,
#   'Wind Speed': 16.11},
#  {'City': 'Xichang',
#   'Cloudiness': 41,
#   'Country': 'CN',
#   'Date': 1566567465,
#   'Humidity': 91,
#   'Lat': 27.88,
#   'Lng': 102.25,
#   'Max Temp': 57.7,
#   'Wind Speed': 2.48},
#  {'City': 'Nouadhibou',
#   'Cloudiness': 67,
#   'Country': 'MR',
#   'Date': 1566567467,
#   'Humidity': 61,
#   'Lat': 20.93,
#   'Lng': -17.03,
#   'Max Temp': 80.6,
#   'Wind Speed': 8.05},
#  {'City': 'Aklavik',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1566566763,
#   'Humidity': 100,
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 41,
#   'Wind Speed': 2.24},
#  {'City': 'Khatanga',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567470,
#   'Humidity': 64,
#   'Lat': 71.98,
#   'Lng': 102.47,
#   'Max Temp': 58.42,
#   'Wind Speed': 3.09},
#  {'City': 'Labuhan',
#   'Cloudiness': 92,
#   'Country': 'ID',
#   'Date': 1566567471,
#   'Humidity': 87,
#   'Lat': -2.54,
#   'Lng': 115.51,
#   'Max Temp': 74.44,
#   'Wind Speed': 2.17},
#  {'City': 'Tuktoyaktuk',
#   'Cloudiness': 87,
#   'Country': 'CA',
#   'Date': 1566566903,
#   'Humidity': 87,
#   'Lat': 69.44,
#   'Lng': -133.03,
#   'Max Temp': 40.5,
#   'Wind Speed': 13.24},
#  {'City': 'San Policarpo',
#   'Cloudiness': 100,
#   'Country': 'PH',
#   'Date': 1566567473,
#   'Humidity': 76,
#   'Lat': 12.18,
#   'Lng': 125.51,
#   'Max Temp': 81.28,
#   'Wind Speed': 10},
#  {'City': 'Anadyr',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1566567475,
#   'Humidity': 93,
#   'Lat': 64.73,
#   'Lng': 177.51,
#   'Max Temp': 37.4,
#   'Wind Speed': 4.47},
#  {'City': 'Arraial do Cabo',
#   'Cloudiness': 75,
#   'Country': 'BR',
#   'Date': 1566567476,
#   'Humidity': 68,
#   'Lat': -22.97,
#   'Lng': -42.02,
#   'Max Temp': 69.8,
#   'Wind Speed': 11.41},
#  {'City': 'Ambon',
#   'Cloudiness': 0,
#   'Country': 'FR',
#   'Date': 1566566883,
#   'Humidity': 47,
#   'Lat': 47.55,
#   'Lng': -2.56,
#   'Max Temp': 87.01,
#   'Wind Speed': 10.29},
#  {'City': 'Tiksi',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': 1566566918,
#   'Humidity': 97,
#   'Lat': 71.64,
#   'Lng': 128.87,
#   'Max Temp': 46.62,
#   'Wind Speed': 3.85},
#  {'City': 'Finschhafen',
#   'Cloudiness': 100,
#   'Country': 'PG',
#   'Date': 1566567479,
#   'Humidity': 99,
#   'Lat': -6.6,
#   'Lng': 147.85,
#   'Max Temp': 63.28,
#   'Wind Speed': 1.5},
#  {'City': 'Qasigiannguit',
#   'Cloudiness': 40,
#   'Country': 'GL',
#   'Date': 1566567480,
#   'Humidity': 75,
#   'Lat': 68.82,
#   'Lng': -51.19,
#   'Max Temp': 42.8,
#   'Wind Speed': 4.7},
#  {'City': 'Longyearbyen',
#   'Cloudiness': 75,
#   'Country': 'NO',
#   'Date': 1566566915,
#   'Humidity': 80,
#   'Lat': 78.22,
#   'Lng': 15.63,
#   'Max Temp': 39.2,
#   'Wind Speed': 8.05},
#  {'City': 'Vestmannaeyjar',
#   'Cloudiness': 90,
#   'Country': 'IS',
#   'Date': 1566567483,
#   'Humidity': 100,
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 51.8,
#   'Wind Speed': 18.34},
#  {'City': 'Vaskut',
#   'Cloudiness': 90,
#   'Country': 'HU',
#   'Date': 1566567484,
#   'Humidity': 54,
#   'Lat': 46.11,
#   'Lng': 18.99,
#   'Max Temp': 84.2,
#   'Wind Speed': 9.17},
#  {'City': 'Marawi',
#   'Cloudiness': 100,
#   'Country': 'PH',
#   'Date': 1566567485,
#   'Humidity': 70,
#   'Lat': 8,
#   'Lng': 124.29,
#   'Max Temp': 81,
#   'Wind Speed': 4},
#  {'City': 'Chuy',
#   'Cloudiness': 0,
#   'Country': 'UY',
#   'Date': 1566567486,
#   'Humidity': 69,
#   'Lat': -33.69,
#   'Lng': -53.46,
#   'Max Temp': 53.38,
#   'Wind Speed': 5.48},
#  {'City': 'Nago',
#   'Cloudiness': 20,
#   'Country': 'IT',
#   'Date': 1566567487,
#   'Humidity': 54,
#   'Lat': 45.88,
#   'Lng': 10.89,
#   'Max Temp': 86,
#   'Wind Speed': 3.36},
#  {'City': 'Ahipara',
#   'Cloudiness': 86,
#   'Country': 'NZ',
#   'Date': 1566567489,
#   'Humidity': 100,
#   'Lat': -35.17,
#   'Lng': 173.16,
#   'Max Temp': 46.99,
#   'Wind Speed': 25.3},
#  {'City': 'Luanda',
#   'Cloudiness': 0,
#   'Country': 'AO',
#   'Date': 1566567349,
#   'Humidity': 78,
#   'Lat': -8.83,
#   'Lng': 13.24,
#   'Max Temp': 75.2,
#   'Wind Speed': 10.29},
#  {'City': 'Karcsa',
#   'Cloudiness': 61,
#   'Country': 'HU',
#   'Date': 1566567492,
#   'Humidity': 51,
#   'Lat': 48.31,
#   'Lng': 21.79,
#   'Max Temp': 84.2,
#   'Wind Speed': 6.71},
#  {'City': 'Lebu',
#   'Cloudiness': 90,
#   'Country': 'ET',
#   'Date': 1566566922,
#   'Humidity': 93,
#   'Lat': 8.96,
#   'Lng': 38.73,
#   'Max Temp': 57.2,
#   'Wind Speed': 6.93},
#  {'City': 'Ekhabi',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567494,
#   'Humidity': 94,
#   'Lat': 53.51,
#   'Lng': 142.97,
#   'Max Temp': 49.78,
#   'Wind Speed': 11.3},
#  {'City': 'Whitehorse',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1566567497,
#   'Humidity': 93,
#   'Lat': 60.72,
#   'Lng': -135.06,
#   'Max Temp': 44.6,
#   'Wind Speed': 5.82},
#  {'City': 'Columbus',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567390,
#   'Humidity': 100,
#   'Lat': 32.46,
#   'Lng': -84.99,
#   'Max Temp': 84.99,
#   'Wind Speed': 2.59},
#  {'City': 'Tambacounda',
#   'Cloudiness': 40,
#   'Country': 'SN',
#   'Date': 1566567499,
#   'Humidity': 79,
#   'Lat': 13.77,
#   'Lng': -13.67,
#   'Max Temp': 86,
#   'Wind Speed': 11.41},
#  {'City': 'Umm Lajj',
#   'Cloudiness': 0,
#   'Country': 'SA',
#   'Date': 1566567256,
#   'Humidity': 78,
#   'Lat': 25.02,
#   'Lng': 37.27,
#   'Max Temp': 86.86,
#   'Wind Speed': 7.43},
#  {'City': 'Ozernovskiy',
#   'Cloudiness': 74,
#   'Country': 'RU',
#   'Date': 1566567501,
#   'Humidity': 96,
#   'Lat': 51.5,
#   'Lng': 156.52,
#   'Max Temp': 45.64,
#   'Wind Speed': 0.38},
#  {'City': 'Leningradskiy',
#   'Cloudiness': 83,
#   'Country': 'RU',
#   'Date': 1566567503,
#   'Humidity': 85,
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 37.9,
#   'Wind Speed': 7.63},
#  {'City': 'Garowe',
#   'Cloudiness': 13,
#   'Country': 'SO',
#   'Date': 1566567504,
#   'Humidity': 31,
#   'Lat': 8.41,
#   'Lng': 48.48,
#   'Max Temp': 90.82,
#   'Wind Speed': 14.94},
#  {'City': 'Benghazi',
#   'Cloudiness': 0,
#   'Country': 'LY',
#   'Date': 1566567505,
#   'Humidity': 63,
#   'Lat': 32.12,
#   'Lng': 20.07,
#   'Max Temp': 83.44,
#   'Wind Speed': 23.47},
#  {'City': 'San Andres',
#   'Cloudiness': 100,
#   'Country': 'PH',
#   'Date': 1566567506,
#   'Humidity': 81,
#   'Lat': 13.32,
#   'Lng': 122.68,
#   'Max Temp': 77.86,
#   'Wind Speed': 2.33},
#  {'City': 'Praia',
#   'Cloudiness': 75,
#   'Country': 'BR',
#   'Date': 1566567507,
#   'Humidity': 64,
#   'Lat': -20.25,
#   'Lng': -43.81,
#   'Max Temp': 69.8,
#   'Wind Speed': 6.93},
#  {'City': 'Salalah',
#   'Cloudiness': 20,
#   'Country': 'OM',
#   'Date': 1566567508,
#   'Humidity': 70,
#   'Lat': 17.01,
#   'Lng': 54.1,
#   'Max Temp': 84.2,
#   'Wind Speed': 10.29},
#  {'City': 'Halifax',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1566567478,
#   'Humidity': 94,
#   'Lat': 44.65,
#   'Lng': -63.58,
#   'Max Temp': 73,
#   'Wind Speed': 5.82},
#  {'City': 'Nyeri',
#   'Cloudiness': 94,
#   'Country': 'KE',
#   'Date': 1566567511,
#   'Humidity': 84,
#   'Lat': -0.42,
#   'Lng': 36.95,
#   'Max Temp': 58.24,
#   'Wind Speed': 4.21},
#  {'City': 'San Cristobal',
#   'Cloudiness': 4,
#   'Country': 'HN',
#   'Date': 1566567512,
#   'Humidity': 53,
#   'Lat': 14.68,
#   'Lng': -86.92,
#   'Max Temp': 78.4,
#   'Wind Speed': 6.26},
#  {'City': 'Lumeje',
#   'Cloudiness': 0,
#   'Country': 'AO',
#   'Date': 1566567513,
#   'Humidity': 16,
#   'Lat': -11.56,
#   'Lng': 20.78,
#   'Max Temp': 83.08,
#   'Wind Speed': 7.92},
#  {'City': 'Saint Anthony',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567516,
#   'Humidity': 87,
#   'Lat': 43.97,
#   'Lng': -111.68,
#   'Max Temp': 46.99,
#   'Wind Speed': 4.88},
#  {'City': 'Kilingi-Nomme',
#   'Cloudiness': 90,
#   'Country': 'EE',
#   'Date': 1566567517,
#   'Humidity': 77,
#   'Lat': 58.15,
#   'Lng': 24.96,
#   'Max Temp': 66.2,
#   'Wind Speed': 12.75},
#  {'City': 'Plainview',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567228,
#   'Humidity': 77,
#   'Lat': 34.18,
#   'Lng': -101.71,
#   'Max Temp': 72,
#   'Wind Speed': 6.93},
#  {'City': 'Auki',
#   'Cloudiness': 100,
#   'Country': 'NG',
#   'Date': 1566567519,
#   'Humidity': 63,
#   'Lat': 12.18,
#   'Lng': 6.51,
#   'Max Temp': 82.9,
#   'Wind Speed': 7.74},
#  {'City': 'La Orilla',
#   'Cloudiness': 98,
#   'Country': 'MX',
#   'Date': 1566567522,
#   'Humidity': 66,
#   'Lat': 18,
#   'Lng': -102.23,
#   'Max Temp': 81.64,
#   'Wind Speed': 4.34},
#  {'City': 'Suzhou',
#   'Cloudiness': 60,
#   'Country': 'CN',
#   'Date': 1566567437,
#   'Humidity': 41,
#   'Lat': 31.3,
#   'Lng': 120.58,
#   'Max Temp': 84,
#   'Wind Speed': 6.98},
#  {'City': 'Lata',
#   'Cloudiness': 35,
#   'Country': 'IN',
#   'Date': 1566567524,
#   'Humidity': 93,
#   'Lat': 30.78,
#   'Lng': 78.62,
#   'Max Temp': 43.66,
#   'Wind Speed': 2.26},
#  {'City': 'Lake Havasu City',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567526,
#   'Humidity': 22,
#   'Lat': 34.47,
#   'Lng': -114.34,
#   'Max Temp': 89.6,
#   'Wind Speed': 8.05},
#  {'City': 'Brandon',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567527,
#   'Humidity': 72,
#   'Lat': 43.59,
#   'Lng': -96.57,
#   'Max Temp': 62.01,
#   'Wind Speed': 3.36},
#  {'City': 'Santa Rosa',
#   'Cloudiness': 100,
#   'Country': 'AR',
#   'Date': 1566567529,
#   'Humidity': 47,
#   'Lat': -36.62,
#   'Lng': -64.29,
#   'Max Temp': 61.84,
#   'Wind Speed': 16.58},
#  {'City': 'Piterka',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567530,
#   'Humidity': 40,
#   'Lat': 50.68,
#   'Lng': 47.44,
#   'Max Temp': 83.8,
#   'Wind Speed': 9.51},
#  {'City': 'Viedma',
#   'Cloudiness': 99,
#   'Country': 'AR',
#   'Date': 1566567532,
#   'Humidity': 42,
#   'Lat': -40.81,
#   'Lng': -62.99,
#   'Max Temp': 59.32,
#   'Wind Speed': 14.2},
#  {'City': 'Zharkent',
#   'Cloudiness': 68,
#   'Country': 'KZ',
#   'Date': 1566567534,
#   'Humidity': 65,
#   'Lat': 44.17,
#   'Lng': 80,
#   'Max Temp': 54.64,
#   'Wind Speed': 4.92},
#  {'City': 'Chitaga',
#   'Cloudiness': 40,
#   'Country': 'CO',
#   'Date': 1566567535,
#   'Humidity': 82,
#   'Lat': 7.14,
#   'Lng': -72.67,
#   'Max Temp': 68,
#   'Wind Speed': 5.82},
#  {'City': 'Baruun-Urt',
#   'Cloudiness': 80,
#   'Country': 'MN',
#   'Date': 1566567536,
#   'Humidity': 55,
#   'Lat': 46.68,
#   'Lng': 113.28,
#   'Max Temp': 58.78,
#   'Wind Speed': 6.13},
#  {'City': 'Waipawa',
#   'Cloudiness': 99,
#   'Country': 'NZ',
#   'Date': 1566567537,
#   'Humidity': 94,
#   'Lat': -39.94,
#   'Lng': 176.59,
#   'Max Temp': 39,
#   'Wind Speed': 1.01},
#  {'City': 'Oksfjord',
#   'Cloudiness': 75,
#   'Country': 'NO',
#   'Date': 1566567538,
#   'Humidity': 76,
#   'Lat': 70.24,
#   'Lng': 22.35,
#   'Max Temp': 55.99,
#   'Wind Speed': 5.82},
#  {'City': 'Los Llanos de Aridane',
#   'Cloudiness': 0,
#   'Country': 'ES',
#   'Date': 1566567539,
#   'Humidity': 73,
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 78.01,
#   'Wind Speed': 14.99},
#  {'City': 'Torbay',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1566567541,
#   'Humidity': 94,
#   'Lat': 47.66,
#   'Lng': -52.73,
#   'Max Temp': 71.6,
#   'Wind Speed': 11.41},
#  {'City': 'Baiima',
#   'Cloudiness': 99,
#   'Country': 'SL',
#   'Date': 1566567542,
#   'Humidity': 66,
#   'Lat': 8.11,
#   'Lng': -11.85,
#   'Max Temp': 84.34,
#   'Wind Speed': 6.04},
#  {'City': 'Erenhot',
#   'Cloudiness': 98,
#   'Country': 'CN',
#   'Date': 1566567543,
#   'Humidity': 30,
#   'Lat': 43.65,
#   'Lng': 111.97,
#   'Max Temp': 75.34,
#   'Wind Speed': 14.74},
#  {'City': 'Ciudad Bolivar',
#   'Cloudiness': 45,
#   'Country': 'VE',
#   'Date': 1566567544,
#   'Humidity': 59,
#   'Lat': 8.12,
#   'Lng': -63.55,
#   'Max Temp': 87.58,
#   'Wind Speed': 7},
#  {'City': 'Dullewala',
#   'Cloudiness': 0,
#   'Country': 'PK',
#   'Date': 1566567546,
#   'Humidity': 21,
#   'Lat': 31.84,
#   'Lng': 71.44,
#   'Max Temp': 102.34,
#   'Wind Speed': 7.65},
#  {'City': 'Jinchang',
#   'Cloudiness': 98,
#   'Country': 'CN',
#   'Date': 1566567547,
#   'Humidity': 51,
#   'Lat': 38.52,
#   'Lng': 102.19,
#   'Max Temp': 61.66,
#   'Wind Speed': 4.54},
#  {'City': 'Kungsbacka',
#   'Cloudiness': 75,
#   'Country': 'SE',
#   'Date': 1566567548,
#   'Humidity': 88,
#   'Lat': 57.49,
#   'Lng': 12.08,
#   'Max Temp': 66.99,
#   'Wind Speed': 13.87},
#  {'City': 'Ler',
#   'Cloudiness': 40,
#   'Country': 'NO',
#   'Date': 1566567549,
#   'Humidity': 67,
#   'Lat': 63.2,
#   'Lng': 10.3,
#   'Max Temp': 62.6,
#   'Wind Speed': 12.75},
#  {'City': 'Hofn',
#   'Cloudiness': 90,
#   'Country': 'IS',
#   'Date': 1566567331,
#   'Humidity': 87,
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 53.6,
#   'Wind Speed': 10.29},
#  {'City': 'Sao Felix do Xingu',
#   'Cloudiness': 0,
#   'Country': 'BR',
#   'Date': 1566567552,
#   'Humidity': 31,
#   'Lat': -6.64,
#   'Lng': -51.99,
#   'Max Temp': 97.84,
#   'Wind Speed': 4.43},
#  {'City': 'Axim',
#   'Cloudiness': 48,
#   'Country': 'GH',
#   'Date': 1566567553,
#   'Humidity': 83,
#   'Lat': 4.87,
#   'Lng': -2.24,
#   'Max Temp': 76.78,
#   'Wind Speed': 13.89},
#  {'City': 'Goderich',
# ...
#   'Cloudiness': 40,
#   'Country': 'RU',
#   'Date': 1566567859,
#   'Humidity': 38,
#   'Lat': 43.24,
#   'Lng': 44.59,
#   'Max Temp': 87.8,
#   'Wind Speed': 4.47},
#  {'City': 'Tooele',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567861,
#   'Humidity': 54,
#   'Lat': 40.53,
#   'Lng': -112.3,
#   'Max Temp': 64,
#   'Wind Speed': 3.36},
#  {'City': 'Nkayi',
#   'Cloudiness': 99,
#   'Country': 'CG',
#   'Date': 1566567862,
#   'Humidity': 44,
#   'Lat': -4.18,
#   'Lng': 13.29,
#   'Max Temp': 88.12,
#   'Wind Speed': 6.85},
#  {'City': 'Puerto Ayacucho',
#   'Cloudiness': 40,
#   'Country': 'CO',
#   'Date': 1566567863,
#   'Humidity': 79,
#   'Lat': 5.66,
#   'Lng': -67.63,
#   'Max Temp': 84.2,
#   'Wind Speed': 10.29},
#  {'City': 'Chaman',
#   'Cloudiness': 0,
#   'Country': 'AF',
#   'Date': 1566567864,
#   'Humidity': 8,
#   'Lat': 30.92,
#   'Lng': 66.46,
#   'Max Temp': 85.42,
#   'Wind Speed': 6.22},
#  {'City': 'Maragogi',
#   'Cloudiness': 23,
#   'Country': 'BR',
#   'Date': 1566567866,
#   'Humidity': 66,
#   'Lat': -9.01,
#   'Lng': -35.22,
#   'Max Temp': 79.3,
#   'Wind Speed': 9.01},
#  {'City': 'Vrangel',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567867,
#   'Humidity': 96,
#   'Lat': 42.73,
#   'Lng': 133.08,
#   'Max Temp': 59.5,
#   'Wind Speed': 2.42},
#  {'City': 'Port Hardy',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1566567868,
#   'Humidity': 93,
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 51.8,
#   'Wind Speed': 16.11},
#  {'City': 'Buta',
#   'Cloudiness': 58,
#   'Country': 'CD',
#   'Date': 1566567870,
#   'Humidity': 51,
#   'Lat': 2.79,
#   'Lng': 24.73,
#   'Max Temp': 87.76,
#   'Wind Speed': 2.3},
#  {'City': 'Neya',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567871,
#   'Humidity': 73,
#   'Lat': 58.29,
#   'Lng': 43.89,
#   'Max Temp': 63.1,
#   'Wind Speed': 4.65},
#  {'City': 'Mangan',
#   'Cloudiness': 99,
#   'Country': 'IN',
#   'Date': 1566567872,
#   'Humidity': 94,
#   'Lat': 27.5,
#   'Lng': 88.54,
#   'Max Temp': 60.4,
#   'Wind Speed': 1.77},
#  {'City': 'Creazzo',
#   'Cloudiness': 20,
#   'Country': 'IT',
#   'Date': 1566567873,
#   'Humidity': 54,
#   'Lat': 45.53,
#   'Lng': 11.48,
#   'Max Temp': 84.99,
#   'Wind Speed': 3.36},
#  {'City': 'Victoria',
#   'Cloudiness': 75,
#   'Country': 'BN',
#   'Date': 1566567738,
#   'Humidity': 83,
#   'Lat': 5.28,
#   'Lng': 115.24,
#   'Max Temp': 84.2,
#   'Wind Speed': 9.48},
#  {'City': 'Rawson',
#   'Cloudiness': 100,
#   'Country': 'AR',
#   'Date': 1566567877,
#   'Humidity': 34,
#   'Lat': -43.3,
#   'Lng': -65.11,
#   'Max Temp': 56.8,
#   'Wind Speed': 27.07},
#  {'City': 'Hobyo',
#   'Cloudiness': 1,
#   'Country': 'SO',
#   'Date': 1566567878,
#   'Humidity': 69,
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 81.1,
#   'Wind Speed': 28.3},
#  {'City': 'Richards Bay',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1566567880,
#   'Humidity': 63,
#   'Lat': -28.77,
#   'Lng': 32.06,
#   'Max Temp': 70.48,
#   'Wind Speed': 3.58},
#  {'City': 'Surgana',
#   'Cloudiness': 85,
#   'Country': 'IN',
#   'Date': 1566567881,
#   'Humidity': 90,
#   'Lat': 20.56,
#   'Lng': 73.64,
#   'Max Temp': 74.08,
#   'Wind Speed': 4},
#  {'City': 'Juneau',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1566567882,
#   'Humidity': 93,
#   'Lat': 58.3,
#   'Lng': -134.42,
#   'Max Temp': 50,
#   'Wind Speed': 6.93},
#  {'City': 'Mecca',
#   'Cloudiness': 0,
#   'Country': 'SA',
#   'Date': 1566567883,
#   'Humidity': 25,
#   'Lat': 21.43,
#   'Lng': 39.83,
#   'Max Temp': 98.2,
#   'Wind Speed': 11.7},
#  {'City': 'Zephyrhills',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': 1566567885,
#   'Humidity': 88,
#   'Lat': 28.23,
#   'Lng': -82.18,
#   'Max Temp': 84.99,
#   'Wind Speed': 8.05},
#  {'City': 'Les Cayes',
#   'Cloudiness': 2,
#   'Country': 'HT',
#   'Date': 1566567887,
#   'Humidity': 73,
#   'Lat': 18.19,
#   'Lng': -73.75,
#   'Max Temp': 83.8,
#   'Wind Speed': 14.99},
#  {'City': 'Kitab',
#   'Cloudiness': 0,
#   'Country': 'UZ',
#   'Date': 1566567888,
#   'Humidity': 26,
#   'Lat': 39.12,
#   'Lng': 66.88,
#   'Max Temp': 84.2,
#   'Wind Speed': 18.34},
#  {'City': 'Komsomolskiy',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567890,
#   'Humidity': 78,
#   'Lat': 67.55,
#   'Lng': 63.78,
#   'Max Temp': 56.8,
#   'Wind Speed': 4.32},
#  {'City': 'Saint-Pierre',
#   'Cloudiness': 0,
#   'Country': 'FR',
#   'Date': 1566567892,
#   'Humidity': 36,
#   'Lat': 48.95,
#   'Lng': 4.24,
#   'Max Temp': 86,
#   'Wind Speed': 10.29},
#  {'City': 'Youghal',
#   'Cloudiness': 75,
#   'Country': 'IE',
#   'Date': 1566567894,
#   'Humidity': 77,
#   'Lat': 51.95,
#   'Lng': -7.85,
#   'Max Temp': 64.99,
#   'Wind Speed': 14.99},
#  {'City': 'Clinton',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1566567895,
#   'Humidity': 93,
#   'Lat': 41.28,
#   'Lng': -72.53,
#   'Max Temp': 68,
#   'Wind Speed': 4.21},
#  {'City': 'Warmbad',
#   'Cloudiness': 0,
#   'Country': 'DE',
#   'Date': 1566567896,
#   'Humidity': 41,
#   'Lat': 50.67,
#   'Lng': 13.08,
#   'Max Temp': 82.99,
#   'Wind Speed': 8.05},
#  {'City': 'Timaru',
#   'Cloudiness': 2,
#   'Country': 'NZ',
#   'Date': 1566567897,
#   'Humidity': 97,
#   'Lat': -44.39,
#   'Lng': 171.25,
#   'Max Temp': 44.01,
#   'Wind Speed': 4.38},
#  {'City': 'Manuk Mangkaw',
#   'Cloudiness': 100,
#   'Country': 'PH',
#   'Date': 1566567898,
#   'Humidity': 77,
#   'Lat': 4.8,
#   'Lng': 119.85,
#   'Max Temp': 82.9,
#   'Wind Speed': 11.05},
#  {'City': 'Hervey Bay',
#   'Cloudiness': 1,
#   'Country': 'AU',
#   'Date': 1566567900,
#   'Humidity': 81,
#   'Lat': -25.3,
#   'Lng': 152.85,
#   'Max Temp': 55,
#   'Wind Speed': 6.93},
#  {'City': 'Mumford',
#   'Cloudiness': 91,
#   'Country': 'GH',
#   'Date': 1566567901,
#   'Humidity': 71,
#   'Lat': 5.26,
#   'Lng': -0.76,
#   'Max Temp': 82.54,
#   'Wind Speed': 7.49},
#  {'City': 'Vila Velha',
#   'Cloudiness': 40,
#   'Country': 'BR',
#   'Date': 1566567902,
#   'Humidity': 51,
#   'Lat': -3.71,
#   'Lng': -38.6,
#   'Max Temp': 86,
#   'Wind Speed': 16.11},
#  {'City': 'Adrar',
#   'Cloudiness': 0,
#   'Country': 'DZ',
#   'Date': 1566567903,
#   'Humidity': 19,
#   'Lat': 27.87,
#   'Lng': -0.29,
#   'Max Temp': 104,
#   'Wind Speed': 9.17},
#  {'City': 'Marsa Matruh',
#   'Cloudiness': 0,
#   'Country': 'EG',
#   'Date': 1566567905,
#   'Humidity': 66,
#   'Lat': 31.35,
#   'Lng': 27.25,
#   'Max Temp': 86,
#   'Wind Speed': 13.87},
#  {'City': 'Eyl',
#   'Cloudiness': 2,
#   'Country': 'SO',
#   'Date': 1566567908,
#   'Humidity': 29,
#   'Lat': 7.98,
#   'Lng': 49.82,
#   'Max Temp': 93.16,
#   'Wind Speed': 16.06},
#  {'City': 'Khandyga',
#   'Cloudiness': 96,
#   'Country': 'RU',
#   'Date': 1566567909,
#   'Humidity': 74,
#   'Lat': 62.65,
#   'Lng': 135.58,
#   'Max Temp': 57.16,
#   'Wind Speed': 0.67},
#  {'City': 'Lobito',
#   'Cloudiness': 75,
#   'Country': 'AO',
#   'Date': 1566567910,
#   'Humidity': 94,
#   'Lat': -12.35,
#   'Lng': 13.55,
#   'Max Temp': 71.6,
#   'Wind Speed': 5.82},
#  {'City': 'Alofi',
#   'Cloudiness': 75,
#   'Country': 'NU',
#   'Date': 1566567911,
#   'Humidity': 94,
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 75.2,
#   'Wind Speed': 6.93},
#  {'City': 'Bissau',
#   'Cloudiness': 40,
#   'Country': 'GW',
#   'Date': 1566567913,
#   'Humidity': 70,
#   'Lat': 11.86,
#   'Lng': -15.58,
#   'Max Temp': 86,
#   'Wind Speed': 16.11},
#  {'City': 'Nola',
#   'Cloudiness': 68,
#   'Country': 'CF',
#   'Date': 1566567914,
#   'Humidity': 65,
#   'Lat': 3.52,
#   'Lng': 16.05,
#   'Max Temp': 82.72,
#   'Wind Speed': 3.02},
#  {'City': 'Troitsk',
#   'Cloudiness': 69,
#   'Country': 'RU',
#   'Date': 1566567915,
#   'Humidity': 77,
#   'Lat': 54.08,
#   'Lng': 61.55,
#   'Max Temp': 68.68,
#   'Wind Speed': 8.46},
#  {'City': 'Werda',
#   'Cloudiness': 0,
#   'Country': 'BW',
#   'Date': 1566567916,
#   'Humidity': 8,
#   'Lat': -25.27,
#   'Lng': 23.28,
#   'Max Temp': 81.82,
#   'Wind Speed': 5.84},
#  {'City': 'Wylie',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567917,
#   'Humidity': 78,
#   'Lat': 33.02,
#   'Lng': -96.54,
#   'Max Temp': 84,
#   'Wind Speed': 6.93},
#  {'City': 'Canby',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1566567919,
#   'Humidity': 87,
#   'Lat': 45.26,
#   'Lng': -122.69,
#   'Max Temp': 55.99,
#   'Wind Speed': 2.17},
#  {'City': 'Cockburn Town',
#   'Cloudiness': 40,
#   'Country': 'TC',
#   'Date': 1566567768,
#   'Humidity': 70,
#   'Lat': 21.46,
#   'Lng': -71.14,
#   'Max Temp': 87.8,
#   'Wind Speed': 13.87},
#  {'City': 'Kamenka',
#   'Cloudiness': 0,
#   'Country': 'MD',
#   'Date': 1566567921,
#   'Humidity': 48,
#   'Lat': 48.03,
#   'Lng': 28.7,
#   'Max Temp': 80.01,
#   'Wind Speed': 5.99},
#  {'City': 'Costa Rica',
#   'Cloudiness': 90,
#   'Country': 'MX',
#   'Date': 1566567922,
#   'Humidity': 100,
#   'Lat': 24.59,
#   'Lng': -107.39,
#   'Max Temp': 75.2,
#   'Wind Speed': 5.61},
#  {'City': 'Sarkikaraagac',
#   'Cloudiness': 0,
#   'Country': 'TR',
#   'Date': 1566567924,
#   'Humidity': 45,
#   'Lat': 38.08,
#   'Lng': 31.37,
#   'Max Temp': 76.24,
#   'Wind Speed': 17.92},
#  {'City': 'Japura',
#   'Cloudiness': 18,
#   'Country': 'ID',
#   'Date': 1566567925,
#   'Humidity': 71,
#   'Lat': -0.42,
#   'Lng': 102.29,
#   'Max Temp': 76.96,
#   'Wind Speed': 3.24},
#  {'City': 'Xuddur',
#   'Cloudiness': 27,
#   'Country': 'SO',
#   'Date': 1566567927,
#   'Humidity': 40,
#   'Lat': 4.12,
#   'Lng': 43.89,
#   'Max Temp': 87.4,
#   'Wind Speed': 21.81},
#  {'City': 'Lanas',
#   'Cloudiness': 0,
#   'Country': 'FR',
#   'Date': 1566567928,
#   'Humidity': 30,
#   'Lat': 44.53,
#   'Lng': 4.4,
#   'Max Temp': 93.2,
#   'Wind Speed': 2.24},
#  {'City': 'Ishim',
#   'Cloudiness': 3,
#   'Country': 'RU',
#   'Date': 1566567930,
#   'Humidity': 77,
#   'Lat': 56.11,
#   'Lng': 69.47,
#   'Max Temp': 66.34,
#   'Wind Speed': 9.51},
#  {'City': 'Mackay',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1566567931,
#   'Humidity': 100,
#   'Lat': 53.65,
#   'Lng': -115.58,
#   'Max Temp': 48.2,
#   'Wind Speed': 5.82},
#  {'City': 'Svetlogorsk',
#   'Cloudiness': 40,
#   'Country': 'RU',
#   'Date': 1566567932,
#   'Humidity': 39,
#   'Lat': 53.14,
#   'Lng': 59.15,
#   'Max Temp': 78.8,
#   'Wind Speed': 13.42},
#  {'City': 'Kuytun',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1566567933,
#   'Humidity': 84,
#   'Lat': 54.34,
#   'Lng': 101.51,
#   'Max Temp': 62.56,
#   'Wind Speed': 7.14},
#  {'City': 'Bolshevik',
#   'Cloudiness': 0,
#   'Country': 'BY',
#   'Date': 1566567934,
#   'Humidity': 46,
#   'Lat': 54.01,
#   'Lng': 27.57,
#   'Max Temp': 69.8,
#   'Wind Speed': 4.47},
#  {'City': 'Sinfra',
#   'Cloudiness': 75,
#   'Country': 'CI',
#   'Date': 1566567936,
#   'Humidity': 78,
#   'Lat': 6.62,
#   'Lng': -5.91,
#   'Max Temp': 80.6,
#   'Wind Speed': 11.41},
#  {'City': 'Iquitos',
#   'Cloudiness': 75,
#   'Country': 'PE',
#   'Date': 1566567937,
#   'Humidity': 100,
#   'Lat': -3.75,
#   'Lng': -73.25,
#   'Max Temp': 73.4,
#   'Wind Speed': 1.12},
#  {'City': 'Abu Samrah',
#   'Cloudiness': 0,
#   'Country': 'SY',
#   'Date': 1566567938,
#   'Humidity': 24,
#   'Lat': 35.3,
#   'Lng': 37.18,
#   'Max Temp': 95.5,
#   'Wind Speed': 17.45},
#  {'City': 'Okha',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1566567940,
#   'Humidity': 94,
#   'Lat': 53.59,
#   'Lng': 142.95,
#   'Max Temp': 49.78,
#   'Wind Speed': 11.3},
#  {'City': 'Istok',
#   'Cloudiness': 0,
#   'Country': 'PL',
#   'Date': 1566567942,
#   'Humidity': 41,
#   'Lat': 52.66,
#   'Lng': 23.48,
#   'Max Temp': 75.99,
#   'Wind Speed': 4.47},
#  {'City': 'The Valley',
#   'Cloudiness': 40,
#   'Country': 'AI',
#   'Date': 1566567943,
#   'Humidity': 74,
#   'Lat': 18.22,
#   'Lng': -63.06,
#   'Max Temp': 86,
#   'Wind Speed': 14.99},
#  {'City': 'Pringsewu',
#   'Cloudiness': 97,
#   'Country': 'ID',
#   'Date': 1566567944,
#   'Humidity': 92,
#   'Lat': -5.36,
#   'Lng': 104.98,
#   'Max Temp': 71.56,
#   'Wind Speed': 3.69},
#  {'City': 'Zhanaozen',
#   'Cloudiness': 0,
#   'Country': 'KZ',
#   'Date': 1566567945,
#   'Humidity': 13,
#   'Lat': 43.35,
#   'Lng': 52.85,
#   'Max Temp': 98.38,
#   'Wind Speed': 12.41},
#  {'City': 'Kiruna',
#   'Cloudiness': 0,
#   'Country': 'SE',
#   'Date': 1566567947,
#   'Humidity': 62,
#   'Lat': 67.86,
#   'Lng': 20.23,
#   'Max Temp': 57.2,
#   'Wind Speed': 8.05},
#  {'City': 'Luau',
#   'Cloudiness': 0,
#   'Country': 'CD',
#   'Date': 1566567948,
#   'Humidity': 15,
#   'Lat': -10.7,
#   'Lng': 22.23,
#   'Max Temp': 86.5,
#   'Wind Speed': 3.38},
#  {'City': 'Alabaster',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': 1566567949,
#   'Humidity': 94,
#   'Lat': 33.24,
#   'Lng': -86.82,
#   'Max Temp': 82,
#   'Wind Speed': 3.36},
#  {'City': 'Sambava',
#   'Cloudiness': 86,
#   'Country': 'MG',
#   'Date': 1566567950,
#   'Humidity': 82,
#   'Lat': -14.27,
#   'Lng': 50.17,
#   'Max Temp': 70.48,
#   'Wind Speed': 4.65},
#  {'City': 'Saint-Joseph',
#   'Cloudiness': 27,
#   'Country': 'FR',
#   'Date': 1566567952,
#   'Humidity': 54,
#   'Lat': 43.56,
#   'Lng': 6.97,
#   'Max Temp': 87.8,
#   'Wind Speed': 9.17},
#  {'City': 'Moscavide',
#   'Cloudiness': 0,
#   'Country': 'PT',
#   'Date': 1566567953,
#   'Humidity': 35,
#   'Lat': 38.78,
#   'Lng': -9.1,
#   'Max Temp': 93,
#   'Wind Speed': 5.82},
#  {'City': 'Pingshan',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1566567954,
#   'Humidity': 79,
#   'Lat': 28.83,
#   'Lng': 104.35,
#   'Max Temp': 75.7,
#   'Wind Speed': 2.33},
#  {'City': 'Nampula',
#   'Cloudiness': 75,
#   'Country': 'MZ',
#   'Date': 1566567955,
#   'Humidity': 54,
#   'Lat': -15.12,
#   'Lng': 39.26,
#   'Max Temp': 78.8,
#   'Wind Speed': 10.29},
#  {'City': 'Kerman',
#   'Cloudiness': 0,
#   'Country': 'IR',
#   'Date': 1566567956,
#   'Humidity': 5,
#   'Lat': 30.29,
#   'Lng': 57.06,
#   'Max Temp': 87.8,
#   'Wind Speed': 9.17},
#  {'City': 'Ketchikan',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1566567959,
#   'Humidity': 100,
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 55.4,
#   'Wind Speed': 14.99},
#  {'City': 'La Asuncion',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': 1566567960,
#   'Humidity': 25,
#   'Lat': -26.05,
#   'Lng': -65.39,
#   'Max Temp': 64.72,
#   'Wind Speed': 6.04},
#  {'City': 'Chaohu',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1566567961,
#   'Humidity': 61,
#   'Lat': 31.63,
#   'Lng': 117.88,
#   'Max Temp': 80.6,
#   'Wind Speed': 6.71},
#  {'City': 'Gold Coast',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1566567963,
#   'Humidity': 87,
#   'Lat': -28,
#   'Lng': 153.41,
#   'Max Temp': 57,
#   'Wind Speed': 4.7},
#  {'City': 'Fauske',
#   'Cloudiness': 75,
#   'Country': 'NO',
#   'Date': 1566567965,
#   'Humidity': 67,
#   'Lat': 67.26,
#   'Lng': 15.4,
#   'Max Temp': 62.01,
#   'Wind Speed': 10.29},
#  {'City': 'Hualmay',
#   'Cloudiness': 100,
#   'Country': 'PE',
#   'Date': 1566567968,
#   'Humidity': 90,
#   'Lat': -11.1,
#   'Lng': -77.61,
#   'Max Temp': 59.5,
#   'Wind Speed': 9.37},
#  {'City': 'Abrau-Dyurso',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1566567969,
#   'Humidity': 41,
#   'Lat': 44.7,
#   'Lng': 37.6,
#   'Max Temp': 93.2,
#   'Wind Speed': 15.66},
#  {'City': 'Mao',
#   'Cloudiness': 75,
#   'Country': 'DO',
#   'Date': 1566567973,
#   'Humidity': 88,
#   'Lat': 19.55,
#   'Lng': -71.08,
#   'Max Temp': 87.01,
#   'Wind Speed': 12.75},
#  {'City': 'Athikia',
#   'Cloudiness': 0,
#   'Country': 'GR',
#   'Date': 1566567974,
#   'Humidity': 24,
#   'Lat': 37.82,
#   'Lng': 22.93,
#   'Max Temp': 95,
#   'Wind Speed': 11.41},
#  {'City': 'Llangefni',
#   'Cloudiness': 75,
#   'Country': 'GB',
#   'Date': 1566567976,
#   'Humidity': 82,
#   'Lat': 53.26,
#   'Lng': -4.31,
#   'Max Temp': 71.01,
#   'Wind Speed': 16.11},
#  {'City': 'Alpena',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1566567977,
#   'Humidity': 72,
#   'Lat': 45.06,
#   'Lng': -83.43,
#   'Max Temp': 64.4,
#   'Wind Speed': 4.7},
#  {'City': 'Ardino',
#   'Cloudiness': 0,
#   'Country': 'BG',
#   'Date': 1566567978,
#   'Humidity': 26,
#   'Lat': 41.58,
#   'Lng': 25.13,
#   'Max Temp': 93.99,
#   'Wind Speed': 10.29},
#  {'City': 'Manzanillo',
#   'Cloudiness': 100,
#   'Country': 'MX',
#   'Date': 1566567979,
#   'Humidity': 68,
#   'Lat': 19.05,
#   'Lng': -104.32,
#   'Max Temp': 82.36,
#   'Wind Speed': 4.9},
#  {'City': 'Maraa',
#   'Cloudiness': 24,
#   'Country': 'BR',
#   'Date': 1566567980,
#   'Humidity': 76,
#   'Lat': -1.83,
#   'Lng': -65.37,
#   'Max Temp': 84.88,
#   'Wind Speed': 2.24},
#  {'City': 'Caramoran',
#   'Cloudiness': 100,
#   'Country': 'PH',
#   'Date': 1566567982,
#   'Humidity': 74,
#   'Lat': 13.98,
#   'Lng': 124.13,
#   'Max Temp': 83.44,
#   'Wind Speed': 23.49},
#  {'City': 'Ballina',
#   'Cloudiness': 75,
#   'Country': 'IE',
#   'Date': 1566567984,
#   'Humidity': 72,
#   'Lat': 54.11,
#   'Lng': -9.15,
#   'Max Temp': 66.99,
#   'Wind Speed': 19.46},
#  {'City': 'Turka',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1566567986,
#   'Humidity': 72,
#   'Lat': 52.95,
#   'Lng': 108.22,
#   'Max Temp': 53.38,
#   'Wind Speed': 4.03},
#  {'City': 'Te Anau',
#   'Cloudiness': 44,
#   'Country': 'NZ',
#   'Date': 1566567987,
#   'Humidity': 85,
#   'Lat': -45.41,
#   'Lng': 167.72,
#   'Max Temp': 38.08,
#   'Wind Speed': 6.33}]

# %%
# create dataframe from city dictionary list
weather_data_df = pd.DataFrame(city_dictionary_list)

# save dataframe as csv
weather_data_df.to_csv(output_data_file, index=False, header=True)

weather_data_df.count()
# Out:
# City          590
# Cloudiness    590
# Country       590
# Date          590
# Humidity      590
# Lat           590
# Lng           590
# Max Temp      590
# Wind Speed    590
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Extract only the data we need (max temp, latitude)
max_temp_list = weather_data_df['Max Temp']
latitude_list = weather_data_df['Lat']

# Build the graph scatter
plt.scatter(latitude_list, max_temp_list, marker='o', edgecolors='black')

# Modify or Configure the Graph to our Needs
plt.grid(True)
plt.title('Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('output_data/LatitudeVsTemp')
plt.show()`

# %%
sns.set_style("darkgrid")
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax = sns.scatterplot(x="Lat", y="Max Temp",
                     palette=cmap, sizes=(10, 200),
                     data=weather_data_df)

ax.set(title = 'Latitude vs. Temperature',xlabel='Latitude', ylabel='Max Temperature (F)')

plt.savefig('output_data/LatitudeVsTemp')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Extract Humidity
humidity_list = weather_data_df['Humidity']

plt.scatter(latitude_list, humidity_list, edgecolors='black')

plt.grid(True)
plt.title('City Latitude vs. Humidty (08/20/2019)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('output_data/CityLatitudeVsHumidity')
plt.show()

# %%
sns.set_style("darkgrid")
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax = sns.scatterplot(x="Lat", y="Humidity",
                     palette=cmap, sizes=(10, 200),
                     data=weather_data_df)

ax.set(title = 'Latitude vs. Humidity',xlabel='Latitude', ylabel='Humidity (%)')

plt.savefig('output_data/LatitudeVsHumidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# get cloudiness data
cloudiness_list = weather_data_df['Cloudiness']

plt.scatter(latitude_list, cloudiness_list, edgecolor ='black')

plt.grid(True)
plt.title('City Latitude vs. Cloudiness (08/20/2019)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('output_data/CityLatitudeVsCloudiness')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# extract windspeed data
windspeed_list = weather_data_df['Wind Speed']

plt.scatter(latitude_list, windspeed_list, edgecolor = 'black')

plt.title('City Latitude vs. Wind Speed (08/20/2019)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('output_data/CityLatitudeVsWindSpeed')
plt.show()

# %% [markdown]
# #### Three observable trends based on the data
# 1. According to the Latitude vs. Temperature scatter plot, it does appear to be hotter closer to the equator.
# 2. There is no apparent correlation between cloudiness and latidude.
# 3. The highest wind speed are further away from the equator / the north and south poles.
